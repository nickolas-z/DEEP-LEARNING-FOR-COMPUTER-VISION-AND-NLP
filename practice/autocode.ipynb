# %%
import os
import random
from tqdm import tqdm

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import plotly.express as px

import torch
import torchvision
from torchvision import transforms
from torch.utils.data import DataLoader,random_split
from torch import nn
import torch.nn.functional as F
import torch.optim as optim

# %%
data_dir = 'data'

train_dataset = torchvision.datasets.FashionMNIST(data_dir, train=True, download=True)
test_dataset  = torchvision.datasets.FashionMNIST(data_dir, train=False, download=True)

print(train_dataset)
type(train_dataset)
# Out:
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz to data/FashionMNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 26421880/26421880 [00:04<00:00, 6417875.88it/s]
# Extracting data/FashionMNIST/raw/train-images-idx3-ubyte.gz to data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz to data/FashionMNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 29515/29515 [00:00<00:00, 276603.23it/s]
# Extracting data/FashionMNIST/raw/train-labels-idx1-ubyte.gz to data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz to data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 4422102/4422102 [00:00<00:00, 5121355.71it/s]
# Extracting data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz to data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz to data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 5148/5148 [00:00<00:00, 5111808.00it/s]
# Extracting data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz to data/FashionMNIST/raw
#
# Dataset FashionMNIST
#     Number of datapoints: 60000
#     Root location: data
#     Split: Train
# torchvision.datasets.mnist.FashionMNIST

# %%
fig, axs = plt.subplots(5, 5, figsize=(6,6))
for ax in axs.flatten():
    img, label = random.choice(train_dataset)
    ax.imshow(np.array(img), cmap='gist_gray')
    ax.set_title('Label: %d' % label)
    ax.set_xticks([])
    ax.set_yticks([])
plt.tight_layout()

# %%
# data to tensors
train_transform = transforms.Compose([
    transforms.ToTensor(),
])
test_transform = transforms.Compose([
    transforms.ToTensor(),
])

# Set the train transform
train_dataset.transform = train_transform
# Set the test transform
test_dataset.transform = test_transform

# %%
m=len(train_dataset)
train_data, val_data = random_split(train_dataset, [int(len(train_dataset)*0.8), int(m*0.2)])

# %%
batch_size=256

train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size)
valid_loader = torch.utils.data.DataLoader(val_data, batch_size=batch_size)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size,shuffle=True)

# %%
class Encoder(nn.Module):

    def __init__(self, encoded_space_dim,fc2_input_dim):
        super().__init__()

        # Convolutional section
        self.encoder_cnn = nn.Sequential(
            # First convolutional layer
            nn.Conv2d(1, 8, 3, stride=2, padding=1),
            #nn.BatchNorm2d(8),
            nn.ReLU(True),
            # Second convolutional layer
            nn.Conv2d(8, 16, 3, stride=2, padding=1),
            nn.BatchNorm2d(16),
            nn.ReLU(True),
            # Third convolutional layer
            nn.Conv2d(16, 32, 3, stride=2, padding=0),
            #nn.BatchNorm2d(32),
            nn.ReLU(True)
        )

        # Flatten layer
        self.flatten = nn.Flatten(start_dim=1)

        # Linear section
        self.encoder_lin = nn.Sequential(
            # First linear layer
            nn.Linear(3 * 3 * 32, 128),
            nn.ReLU(True),
            # Second linear layer
            nn.Linear(128, encoded_space_dim)
        )

    def forward(self, x):
        # Apply convolutions
        x = self.encoder_cnn(x)
        # Flatten
        x = self.flatten(x)
        # # Apply linear layers
        x = self.encoder_lin(x)
        return x

# %%
class Decoder(nn.Module):

    def __init__(self, encoded_space_dim,fc2_input_dim=128):
        super().__init__()

        # Linear section
        self.decoder_lin = nn.Sequential(
            # First linear layer
            nn.Linear(encoded_space_dim, 128),
            nn.ReLU(True),
            # Second linear layer
            nn.Linear(128, 3 * 3 * 32),
            nn.ReLU(True)
        )

        # Unflatten
        self.unflatten = nn.Unflatten(dim=1, unflattened_size=(32, 3, 3))

        # Convolutional section
        self.decoder_conv = nn.Sequential(
            # First transposed convolution
            nn.ConvTranspose2d(32, 16, 3, stride=2, output_padding=0),
            nn.BatchNorm2d(16),
            nn.ReLU(True),
            # Second transposed convolution
            nn.ConvTranspose2d(16, 8, 3, stride=2, padding=1, output_padding=1),
            nn.BatchNorm2d(8),
            nn.ReLU(True),
            # Third transposed convolution
            nn.ConvTranspose2d(8, 1, 3, stride=2, padding=1, output_padding=1)
        )

    def forward(self, x):
        # Apply linear layers
        x = self.decoder_lin(x)
        # Unflatten
        x = self.unflatten(x)
        # Apply transposed convolutions
        x = self.decoder_conv(x)
        # Apply a sigmoid to force the output to be between 0 and 1 (valid pixel values)
        x = torch.sigmoid(x)
        return x

# %%
# Set the random seed for reproducible results
torch.manual_seed(42)

# Initialize the two networks
dim = 4

encoder = Encoder(encoded_space_dim=dim, fc2_input_dim=128)
decoder = Decoder(encoded_space_dim=dim, fc2_input_dim=128)

# %%
img, _ = test_dataset[0]
img = img.unsqueeze(0) # Add the batch dimension in the first axis
print('Original image shape:', img.shape)

# Encode the image
img_enc = encoder(img)
print('Encoded image shape:', img_enc.shape)

# Decode the image
dec_img = decoder(img_enc)
print('Decoded image shape:', dec_img.shape)
# Out:
# Original image shape: torch.Size([1, 1, 28, 28])
# Encoded image shape: torch.Size([1, 4])
# Decoded image shape: torch.Size([1, 1, 28, 28])

# %%
# Define the loss function
loss_fn = torch.nn.MSELoss()

# Define an optimizer (both for the encoder and the decoder!)
lr= 0.001

params_to_optimize = [
    {'params': encoder.parameters()},
    {'params': decoder.parameters()}
]

optim = torch.optim.Adam(params_to_optimize, lr=lr, weight_decay=1e-05)

# Check if the GPU is available
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
print(f'Selected device: {device}')

# Move both the encoder and the decoder to the selected device
encoder.to(device)
# Out:
# Selected device: cpu
# Encoder(
#   (encoder_cnn): Sequential(
#     (0): Conv2d(1, 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(8, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (3): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (4): ReLU(inplace=True)
#     (5): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2))
#     (6): ReLU(inplace=True)
#   )
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (encoder_lin): Sequential(
#     (0): Linear(in_features=288, out_features=128, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Linear(in_features=128, out_features=4, bias=True)
#   )
# )

# %%
decoder.to(device)
# Out:
# Decoder(
#   (decoder_lin): Sequential(
#     (0): Linear(in_features=4, out_features=128, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Linear(in_features=128, out_features=288, bias=True)
#     (3): ReLU(inplace=True)
#   )
#   (unflatten): Unflatten(dim=1, unflattened_size=(32, 3, 3))
#   (decoder_conv): Sequential(
#     (0): ConvTranspose2d(32, 16, kernel_size=(3, 3), stride=(2, 2))
#     (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): ConvTranspose2d(16, 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#     (4): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): ConvTranspose2d(8, 1, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#   )
# )

# %%
def train_epoch(encoder, decoder, device, dataloader, loss_fn, optimizer):
    # Set train mode for both the encoder and the decoder
    encoder.train()
    decoder.train()
    train_loss = []
    # Iterate the dataloader (we do not need the label values, this is unsupervised learning)
    for image_batch, _ in dataloader: # with "_" we just ignore the labels (the second element of the dataloader tuple)
        # Move tensor to the proper device
        image_batch = image_batch.to(device)
        # Encode data
        encoded_data = encoder(image_batch)
        # Decode data
        decoded_data = decoder(encoded_data)
        # Evaluate loss
        loss = loss_fn(decoded_data, image_batch)
        # Backward pass
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        # Print batch loss
        print('\\t partial train loss (single batch): %f' % (loss.data))
        train_loss.append(loss.detach().cpu().numpy())

    return np.mean(train_loss)
def test_epoch(encoder, decoder, device, dataloader, loss_fn):
    # Set evaluation mode for encoder and decoder
    encoder.eval()
    decoder.eval()
    with torch.no_grad(): # No need to track the gradients
        # Define the lists to store the outputs for each batch
        conc_out = []
        conc_label = []
        for image_batch, _ in dataloader:
            # Move tensor to the proper device
            image_batch = image_batch.to(device)
            # Encode data
            encoded_data = encoder(image_batch)
            # Decode data
            decoded_data = decoder(encoded_data)
            # Append the network output and the original image to the lists
            conc_out.append(decoded_data.cpu())
            conc_label.append(image_batch.cpu())
        # Create a single tensor with all the values in the lists
        conc_out = torch.cat(conc_out)
        conc_label = torch.cat(conc_label)
        # Evaluate global loss
        val_loss = loss_fn(conc_out, conc_label)
    return val_loss.data

# %%
def plot_ae_outputs(encoder,decoder,n=5):
    plt.figure(figsize=(10,4.5))
    for i in range(n):
        ax = plt.subplot(2,n,i+1)
        img = test_dataset[i][0].unsqueeze(0).to(device)
        encoder.eval()
        decoder.eval()
        with torch.no_grad():
            rec_img  = decoder(encoder(img))
        plt.imshow(img.cpu().squeeze().numpy(), cmap='gist_gray')
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
        if i == n//2:
            ax.set_title('Original images')
        ax = plt.subplot(2, n, i + 1 + n)
        plt.imshow(rec_img.cpu().squeeze().numpy(), cmap='gist_gray')
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
        if i == n//2:
            ax.set_title('Reconstructed images')
    plt.show()

# %%
num_epochs = 30
history={'train_loss':[],'val_loss':[]}

for epoch in range(num_epochs):
    train_loss = train_epoch(encoder,decoder,device,train_loader,loss_fn,optim)
    val_loss = test_epoch(encoder,decoder,device,valid_loader,loss_fn)

    print('\\n EPOCH {}/{} \\t train loss {:.3f} \\t val loss {:.3f}'.format(epoch + 1, num_epochs,train_loss,val_loss))

    history['train_loss'].append(train_loss)
    history['val_loss'].append(val_loss)
    plot_ae_outputs(encoder,decoder,n=5)
# Out:
# \t partial train loss (single batch): 0.242227
# \t partial train loss (single batch): 0.240280
# \t partial train loss (single batch): 0.234161
# \t partial train loss (single batch): 0.225795
# \t partial train loss (single batch): 0.227451
# \t partial train loss (single batch): 0.224555
# \t partial train loss (single batch): 0.211810
# \t partial train loss (single batch): 0.216894
# \t partial train loss (single batch): 0.212843
# \t partial train loss (single batch): 0.208753
# \t partial train loss (single batch): 0.201973
# \t partial train loss (single batch): 0.202356
# \t partial train loss (single batch): 0.197917
# \t partial train loss (single batch): 0.192090
# \t partial train loss (single batch): 0.194559
# \t partial train loss (single batch): 0.189089
# \t partial train loss (single batch): 0.187922
# \t partial train loss (single batch): 0.187857
# \t partial train loss (single batch): 0.194796
# \t partial train loss (single batch): 0.187722
# \t partial train loss (single batch): 0.183962
# \t partial train loss (single batch): 0.178102
# \t partial train loss (single batch): 0.175342
# \t partial train loss (single batch): 0.175968
# \t partial train loss (single batch): 0.172764
# \t partial train loss (single batch): 0.172173
# \t partial train loss (single batch): 0.175802
# \t partial train loss (single batch): 0.174470
# \t partial train loss (single batch): 0.168847
# \t partial train loss (single batch): 0.169650
# \t partial train loss (single batch): 0.169870
# \t partial train loss (single batch): 0.167464
# \t partial train loss (single batch): 0.168324
# \t partial train loss (single batch): 0.166114
# \t partial train loss (single batch): 0.162111
# \t partial train loss (single batch): 0.164566
# \t partial train loss (single batch): 0.162544
# \t partial train loss (single batch): 0.158979
# \t partial train loss (single batch): 0.154351
# \t partial train loss (single batch): 0.157247
# \t partial train loss (single batch): 0.159490
# \t partial train loss (single batch): 0.156289
# \t partial train loss (single batch): 0.155412
# \t partial train loss (single batch): 0.151724
# \t partial train loss (single batch): 0.148258
# \t partial train loss (single batch): 0.149275
# \t partial train loss (single batch): 0.150485
# \t partial train loss (single batch): 0.147518
# \t partial train loss (single batch): 0.146789
# \t partial train loss (single batch): 0.144468
# \t partial train loss (single batch): 0.147344
# \t partial train loss (single batch): 0.145622
# \t partial train loss (single batch): 0.140666
# \t partial train loss (single batch): 0.142840
# \t partial train loss (single batch): 0.141809
# \t partial train loss (single batch): 0.141289
# \t partial train loss (single batch): 0.140819
# \t partial train loss (single batch): 0.138436
# \t partial train loss (single batch): 0.137495
# \t partial train loss (single batch): 0.135282
# \t partial train loss (single batch): 0.136656
# \t partial train loss (single batch): 0.137117
# \t partial train loss (single batch): 0.134840
# \t partial train loss (single batch): 0.133632
# \t partial train loss (single batch): 0.135282
# \t partial train loss (single batch): 0.130427
# \t partial train loss (single batch): 0.128763
# \t partial train loss (single batch): 0.130336
# \t partial train loss (single batch): 0.127535
# \t partial train loss (single batch): 0.128855
# \t partial train loss (single batch): 0.128013
# \t partial train loss (single batch): 0.130150
# \t partial train loss (single batch): 0.123698
# \t partial train loss (single batch): 0.127301
# \t partial train loss (single batch): 0.122305
# \t partial train loss (single batch): 0.121788
# \t partial train loss (single batch): 0.121140
# \t partial train loss (single batch): 0.122800
# \t partial train loss (single batch): 0.122287
# \t partial train loss (single batch): 0.122751
# \t partial train loss (single batch): 0.119022
# \t partial train loss (single batch): 0.118175
# \t partial train loss (single batch): 0.116234
# \t partial train loss (single batch): 0.117020
# \t partial train loss (single batch): 0.115274
# \t partial train loss (single batch): 0.117617
# \t partial train loss (single batch): 0.116640
# \t partial train loss (single batch): 0.114902
# \t partial train loss (single batch): 0.111795
# \t partial train loss (single batch): 0.113113
# \t partial train loss (single batch): 0.109294
# \t partial train loss (single batch): 0.110297
# \t partial train loss (single batch): 0.110625
# \t partial train loss (single batch): 0.108475
# \t partial train loss (single batch): 0.109035
# \t partial train loss (single batch): 0.107145
# \t partial train loss (single batch): 0.105488
# \t partial train loss (single batch): 0.105675
# \t partial train loss (single batch): 0.108583
# \t partial train loss (single batch): 0.104941
# \t partial train loss (single batch): 0.103003
# \t partial train loss (single batch): 0.100150
# \t partial train loss (single batch): 0.102923
# \t partial train loss (single batch): 0.101950
# \t partial train loss (single batch): 0.099310
# \t partial train loss (single batch): 0.101894
# \t partial train loss (single batch): 0.100664
# \t partial train loss (single batch): 0.096761
# \t partial train loss (single batch): 0.101604
# \t partial train loss (single batch): 0.096447
# \t partial train loss (single batch): 0.096497
# \t partial train loss (single batch): 0.093104
# \t partial train loss (single batch): 0.094336
# \t partial train loss (single batch): 0.094638
# \t partial train loss (single batch): 0.094331
# \t partial train loss (single batch): 0.090475
# \t partial train loss (single batch): 0.090686
# \t partial train loss (single batch): 0.091645
# \t partial train loss (single batch): 0.089600
# \t partial train loss (single batch): 0.090971
# \t partial train loss (single batch): 0.089088
# \t partial train loss (single batch): 0.088742
# \t partial train loss (single batch): 0.086801
# \t partial train loss (single batch): 0.088233
# \t partial train loss (single batch): 0.085932
# \t partial train loss (single batch): 0.086487
# \t partial train loss (single batch): 0.082788
# \t partial train loss (single batch): 0.085640
# \t partial train loss (single batch): 0.082662
# \t partial train loss (single batch): 0.082669
# \t partial train loss (single batch): 0.083250
# \t partial train loss (single batch): 0.080032
# \t partial train loss (single batch): 0.079908
# \t partial train loss (single batch): 0.079053
# \t partial train loss (single batch): 0.078943
# \t partial train loss (single batch): 0.078366
# \t partial train loss (single batch): 0.076818
# \t partial train loss (single batch): 0.076391
# \t partial train loss (single batch): 0.076159
# \t partial train loss (single batch): 0.078707
# \t partial train loss (single batch): 0.077308
# \t partial train loss (single batch): 0.076523
# \t partial train loss (single batch): 0.074278
# \t partial train loss (single batch): 0.074088
# \t partial train loss (single batch): 0.075157
# \t partial train loss (single batch): 0.074982
# \t partial train loss (single batch): 0.072608
# \t partial train loss (single batch): 0.071018
# \t partial train loss (single batch): 0.070702
# \t partial train loss (single batch): 0.070042
# \t partial train loss (single batch): 0.071938
# \t partial train loss (single batch): 0.070849
# \t partial train loss (single batch): 0.067436
# \t partial train loss (single batch): 0.068979
# \t partial train loss (single batch): 0.071600
# \t partial train loss (single batch): 0.070329
# \t partial train loss (single batch): 0.068042
# \t partial train loss (single batch): 0.065670
# \t partial train loss (single batch): 0.067992
# \t partial train loss (single batch): 0.064994
# \t partial train loss (single batch): 0.065230
# \t partial train loss (single batch): 0.064063
# \t partial train loss (single batch): 0.065984
# \t partial train loss (single batch): 0.066410
# \t partial train loss (single batch): 0.064609
# \t partial train loss (single batch): 0.062495
# \t partial train loss (single batch): 0.063241
# \t partial train loss (single batch): 0.061322
# \t partial train loss (single batch): 0.063182
# \t partial train loss (single batch): 0.062071
# \t partial train loss (single batch): 0.060152
# \t partial train loss (single batch): 0.060393
# \t partial train loss (single batch): 0.062594
# \t partial train loss (single batch): 0.061043
# \t partial train loss (single batch): 0.058411
# \t partial train loss (single batch): 0.058858
# \t partial train loss (single batch): 0.060259
# \t partial train loss (single batch): 0.058513
# \t partial train loss (single batch): 0.058107
# \t partial train loss (single batch): 0.058230
# \t partial train loss (single batch): 0.057626
# \t partial train loss (single batch): 0.057602
# \t partial train loss (single batch): 0.056602
# \t partial train loss (single batch): 0.055643
# \t partial train loss (single batch): 0.056909
# \t partial train loss (single batch): 0.053996
# \t partial train loss (single batch): 0.055543
# \t partial train loss (single batch): 0.054550
# \n EPOCH 1/30 \t train loss 0.117 \t val loss 0.054
# \t partial train loss (single batch): 0.053869
# \t partial train loss (single batch): 0.054042
# \t partial train loss (single batch): 0.053741
# \t partial train loss (single batch): 0.053126
# \t partial train loss (single batch): 0.054666
# \t partial train loss (single batch): 0.054494
# \t partial train loss (single batch): 0.051909
# \t partial train loss (single batch): 0.054486
# \t partial train loss (single batch): 0.053925
# \t partial train loss (single batch): 0.052198
# \t partial train loss (single batch): 0.050620
# \t partial train loss (single batch): 0.050721
# \t partial train loss (single batch): 0.050672
# \t partial train loss (single batch): 0.049031
# \t partial train loss (single batch): 0.050937
# \t partial train loss (single batch): 0.050063
# \t partial train loss (single batch): 0.050507
# \t partial train loss (single batch): 0.048439
# \t partial train loss (single batch): 0.052716
# \t partial train loss (single batch): 0.050745
# \t partial train loss (single batch): 0.049207
# \t partial train loss (single batch): 0.047441
# \t partial train loss (single batch): 0.047901
# \t partial train loss (single batch): 0.047623
# \t partial train loss (single batch): 0.046830
# \t partial train loss (single batch): 0.048804
# \t partial train loss (single batch): 0.048907
# \t partial train loss (single batch): 0.048121
# \t partial train loss (single batch): 0.046505
# \t partial train loss (single batch): 0.045893
# \t partial train loss (single batch): 0.048195
# \t partial train loss (single batch): 0.046519
# \t partial train loss (single batch): 0.047201
# \t partial train loss (single batch): 0.046790
# \t partial train loss (single batch): 0.044919
# \t partial train loss (single batch): 0.046050
# \t partial train loss (single batch): 0.045773
# \t partial train loss (single batch): 0.044938
# \t partial train loss (single batch): 0.042620
# \t partial train loss (single batch): 0.044225
# \t partial train loss (single batch): 0.044910
# \t partial train loss (single batch): 0.043799
# \t partial train loss (single batch): 0.044011
# \t partial train loss (single batch): 0.042856
# \t partial train loss (single batch): 0.042790
# \t partial train loss (single batch): 0.042268
# \t partial train loss (single batch): 0.042304
# \t partial train loss (single batch): 0.042729
# \t partial train loss (single batch): 0.042759
# \t partial train loss (single batch): 0.042305
# \t partial train loss (single batch): 0.041939
# \t partial train loss (single batch): 0.042383
# \t partial train loss (single batch): 0.040510
# \t partial train loss (single batch): 0.041702
# \t partial train loss (single batch): 0.041447
# \t partial train loss (single batch): 0.041460
# \t partial train loss (single batch): 0.041470
# \t partial train loss (single batch): 0.042759
# \t partial train loss (single batch): 0.040489
# \t partial train loss (single batch): 0.040821
# \t partial train loss (single batch): 0.042390
# \t partial train loss (single batch): 0.040693
# \t partial train loss (single batch): 0.040825
# \t partial train loss (single batch): 0.040234
# \t partial train loss (single batch): 0.041679
# \t partial train loss (single batch): 0.039371
# \t partial train loss (single batch): 0.040207
# \t partial train loss (single batch): 0.040204
# \t partial train loss (single batch): 0.038039
# \t partial train loss (single batch): 0.039916
# \t partial train loss (single batch): 0.040139
# \t partial train loss (single batch): 0.039219
# \t partial train loss (single batch): 0.038380
# \t partial train loss (single batch): 0.040027
# \t partial train loss (single batch): 0.038283
# \t partial train loss (single batch): 0.038847
# \t partial train loss (single batch): 0.039785
# \t partial train loss (single batch): 0.038880
# \t partial train loss (single batch): 0.038115
# \t partial train loss (single batch): 0.039309
# \t partial train loss (single batch): 0.037359
# \t partial train loss (single batch): 0.037420
# \t partial train loss (single batch): 0.038071
# \t partial train loss (single batch): 0.038686
# \t partial train loss (single batch): 0.037440
# \t partial train loss (single batch): 0.037567
# \t partial train loss (single batch): 0.037322
# \t partial train loss (single batch): 0.037603
# \t partial train loss (single batch): 0.036163
# \t partial train loss (single batch): 0.036502
# \t partial train loss (single batch): 0.035247
# \t partial train loss (single batch): 0.035787
# \t partial train loss (single batch): 0.037191
# \t partial train loss (single batch): 0.035969
# \t partial train loss (single batch): 0.036993
# \t partial train loss (single batch): 0.035730
# \t partial train loss (single batch): 0.036034
# \t partial train loss (single batch): 0.036531
# \t partial train loss (single batch): 0.037239
# \t partial train loss (single batch): 0.036549
# \t partial train loss (single batch): 0.035143
# \t partial train loss (single batch): 0.034694
# \t partial train loss (single batch): 0.036055
# \t partial train loss (single batch): 0.036261
# \t partial train loss (single batch): 0.034829
# \t partial train loss (single batch): 0.036071
# \t partial train loss (single batch): 0.036132
# \t partial train loss (single batch): 0.035167
# \t partial train loss (single batch): 0.036558
# \t partial train loss (single batch): 0.034319
# \t partial train loss (single batch): 0.035994
# \t partial train loss (single batch): 0.033685
# \t partial train loss (single batch): 0.035018
# \t partial train loss (single batch): 0.034342
# \t partial train loss (single batch): 0.035117
# \t partial train loss (single batch): 0.034245
# \t partial train loss (single batch): 0.033965
# \t partial train loss (single batch): 0.034634
# \t partial train loss (single batch): 0.033557
# \t partial train loss (single batch): 0.035356
# \t partial train loss (single batch): 0.034663
# \t partial train loss (single batch): 0.033530
# \t partial train loss (single batch): 0.032941
# \t partial train loss (single batch): 0.034673
# \t partial train loss (single batch): 0.033883
# \t partial train loss (single batch): 0.033090
# \t partial train loss (single batch): 0.032167
# \t partial train loss (single batch): 0.034397
# \t partial train loss (single batch): 0.033761
# \t partial train loss (single batch): 0.032765
# \t partial train loss (single batch): 0.033038
# \t partial train loss (single batch): 0.032043
# \t partial train loss (single batch): 0.033046
# \t partial train loss (single batch): 0.032716
# \t partial train loss (single batch): 0.032410
# \t partial train loss (single batch): 0.033719
# \t partial train loss (single batch): 0.032425
# \t partial train loss (single batch): 0.030889
# \t partial train loss (single batch): 0.032824
# \t partial train loss (single batch): 0.033878
# \t partial train loss (single batch): 0.033662
# \t partial train loss (single batch): 0.033268
# \t partial train loss (single batch): 0.032205
# \t partial train loss (single batch): 0.031347
# \t partial train loss (single batch): 0.033432
# \t partial train loss (single batch): 0.033011
# \t partial train loss (single batch): 0.031538
# \t partial train loss (single batch): 0.032843
# \t partial train loss (single batch): 0.031648
# \t partial train loss (single batch): 0.031209
# \t partial train loss (single batch): 0.032884
# \t partial train loss (single batch): 0.031777
# \t partial train loss (single batch): 0.031509
# \t partial train loss (single batch): 0.031992
# \t partial train loss (single batch): 0.033813
# \t partial train loss (single batch): 0.032794
# \t partial train loss (single batch): 0.031534
# \t partial train loss (single batch): 0.032055
# \t partial train loss (single batch): 0.032084
# \t partial train loss (single batch): 0.031878
# \t partial train loss (single batch): 0.031508
# \t partial train loss (single batch): 0.030535
# \t partial train loss (single batch): 0.031705
# \t partial train loss (single batch): 0.032331
# \t partial train loss (single batch): 0.030483
# \t partial train loss (single batch): 0.030778
# \t partial train loss (single batch): 0.030424
# \t partial train loss (single batch): 0.030163
# \t partial train loss (single batch): 0.031471
# \t partial train loss (single batch): 0.029435
# \t partial train loss (single batch): 0.029730
# \t partial train loss (single batch): 0.031992
# \t partial train loss (single batch): 0.031630
# \t partial train loss (single batch): 0.030757
# \t partial train loss (single batch): 0.029902
# \t partial train loss (single batch): 0.030435
# \t partial train loss (single batch): 0.030089
# \t partial train loss (single batch): 0.029511
# \t partial train loss (single batch): 0.030966
# \t partial train loss (single batch): 0.030458
# \t partial train loss (single batch): 0.029771
# \t partial train loss (single batch): 0.030350
# \t partial train loss (single batch): 0.029683
# \t partial train loss (single batch): 0.029578
# \t partial train loss (single batch): 0.030579
# \t partial train loss (single batch): 0.028661
# \t partial train loss (single batch): 0.029450
# \t partial train loss (single batch): 0.029298
# \n EPOCH 2/30 \t train loss 0.038 \t val loss 0.030
# \t partial train loss (single batch): 0.030210
# \t partial train loss (single batch): 0.029285
# \t partial train loss (single batch): 0.028618
# \t partial train loss (single batch): 0.029150
# \t partial train loss (single batch): 0.029704
# \t partial train loss (single batch): 0.029931
# \t partial train loss (single batch): 0.029425
# \t partial train loss (single batch): 0.030825
# \t partial train loss (single batch): 0.030949
# \t partial train loss (single batch): 0.029672
# \t partial train loss (single batch): 0.029340
# \t partial train loss (single batch): 0.028869
# \t partial train loss (single batch): 0.029370
# \t partial train loss (single batch): 0.028755
# \t partial train loss (single batch): 0.029720
# \t partial train loss (single batch): 0.029739
# \t partial train loss (single batch): 0.030729
# \t partial train loss (single batch): 0.027905
# \t partial train loss (single batch): 0.030469
# \t partial train loss (single batch): 0.029900
# \t partial train loss (single batch): 0.029023
# \t partial train loss (single batch): 0.028139
# \t partial train loss (single batch): 0.029259
# \t partial train loss (single batch): 0.028829
# \t partial train loss (single batch): 0.028415
# \t partial train loss (single batch): 0.031058
# \t partial train loss (single batch): 0.029998
# \t partial train loss (single batch): 0.029421
# \t partial train loss (single batch): 0.028648
# \t partial train loss (single batch): 0.027793
# \t partial train loss (single batch): 0.030442
# \t partial train loss (single batch): 0.028473
# \t partial train loss (single batch): 0.029358
# \t partial train loss (single batch): 0.029537
# \t partial train loss (single batch): 0.028021
# \t partial train loss (single batch): 0.028754
# \t partial train loss (single batch): 0.028634
# \t partial train loss (single batch): 0.028835
# \t partial train loss (single batch): 0.027024
# \t partial train loss (single batch): 0.028375
# \t partial train loss (single batch): 0.028195
# \t partial train loss (single batch): 0.027610
# \t partial train loss (single batch): 0.028160
# \t partial train loss (single batch): 0.027622
# \t partial train loss (single batch): 0.028250
# \t partial train loss (single batch): 0.027384
# \t partial train loss (single batch): 0.027269
# \t partial train loss (single batch): 0.027910
# \t partial train loss (single batch): 0.028641
# \t partial train loss (single batch): 0.028163
# \t partial train loss (single batch): 0.026884
# \t partial train loss (single batch): 0.027840
# \t partial train loss (single batch): 0.026688
# \t partial train loss (single batch): 0.027667
# \t partial train loss (single batch): 0.027295
# \t partial train loss (single batch): 0.027503
# \t partial train loss (single batch): 0.027638
# \t partial train loss (single batch): 0.029275
# \t partial train loss (single batch): 0.026781
# \t partial train loss (single batch): 0.028070
# \t partial train loss (single batch): 0.028811
# \t partial train loss (single batch): 0.027188
# \t partial train loss (single batch): 0.027660
# \t partial train loss (single batch): 0.027236
# \t partial train loss (single batch): 0.028831
# \t partial train loss (single batch): 0.027003
# \t partial train loss (single batch): 0.028263
# \t partial train loss (single batch): 0.027544
# \t partial train loss (single batch): 0.026011
# \t partial train loss (single batch): 0.027720
# \t partial train loss (single batch): 0.028366
# \t partial train loss (single batch): 0.026785
# \t partial train loss (single batch): 0.027276
# \t partial train loss (single batch): 0.028303
# \t partial train loss (single batch): 0.026897
# \t partial train loss (single batch): 0.027546
# \t partial train loss (single batch): 0.029065
# \t partial train loss (single batch): 0.027437
# \t partial train loss (single batch): 0.026409
# \t partial train loss (single batch): 0.028270
# \t partial train loss (single batch): 0.026481
# \t partial train loss (single batch): 0.026599
# \t partial train loss (single batch): 0.027898
# \t partial train loss (single batch): 0.027947
# \t partial train loss (single batch): 0.027167
# \t partial train loss (single batch): 0.026730
# \t partial train loss (single batch): 0.026434
# \t partial train loss (single batch): 0.026913
# \t partial train loss (single batch): 0.026201
# \t partial train loss (single batch): 0.026190
# \t partial train loss (single batch): 0.025536
# \t partial train loss (single batch): 0.025916
# \t partial train loss (single batch): 0.027095
# \t partial train loss (single batch): 0.026256
# \t partial train loss (single batch): 0.027171
# \t partial train loss (single batch): 0.026158
# \t partial train loss (single batch): 0.026762
# \t partial train loss (single batch): 0.027243
# \t partial train loss (single batch): 0.027140
# \t partial train loss (single batch): 0.026970
# \t partial train loss (single batch): 0.025814
# \t partial train loss (single batch): 0.026012
# \t partial train loss (single batch): 0.026871
# \t partial train loss (single batch): 0.027046
# \t partial train loss (single batch): 0.026194
# \t partial train loss (single batch): 0.027109
# \t partial train loss (single batch): 0.027066
# \t partial train loss (single batch): 0.026777
# \t partial train loss (single batch): 0.027399
# \t partial train loss (single batch): 0.025740
# \t partial train loss (single batch): 0.027366
# \t partial train loss (single batch): 0.025489
# \t partial train loss (single batch): 0.026893
# \t partial train loss (single batch): 0.026053
# \t partial train loss (single batch): 0.026840
# \t partial train loss (single batch): 0.026332
# \t partial train loss (single batch): 0.025953
# \t partial train loss (single batch): 0.026627
# \t partial train loss (single batch): 0.025594
# \t partial train loss (single batch): 0.027278
# \t partial train loss (single batch): 0.026867
# \t partial train loss (single batch): 0.025427
# \t partial train loss (single batch): 0.025036
# \t partial train loss (single batch): 0.026848
# \t partial train loss (single batch): 0.026205
# \t partial train loss (single batch): 0.025218
# \t partial train loss (single batch): 0.024740
# \t partial train loss (single batch): 0.026732
# \t partial train loss (single batch): 0.026403
# \t partial train loss (single batch): 0.025324
# \t partial train loss (single batch): 0.025695
# \t partial train loss (single batch): 0.024925
# \t partial train loss (single batch): 0.026054
# \t partial train loss (single batch): 0.025830
# \t partial train loss (single batch): 0.025394
# \t partial train loss (single batch): 0.026997
# \t partial train loss (single batch): 0.025720
# \t partial train loss (single batch): 0.023924
# \t partial train loss (single batch): 0.026087
# \t partial train loss (single batch): 0.026898
# \t partial train loss (single batch): 0.026954
# \t partial train loss (single batch): 0.026560
# \t partial train loss (single batch): 0.025621
# \t partial train loss (single batch): 0.024739
# \t partial train loss (single batch): 0.026760
# \t partial train loss (single batch): 0.026107
# \t partial train loss (single batch): 0.025074
# \t partial train loss (single batch): 0.026883
# \t partial train loss (single batch): 0.025346
# \t partial train loss (single batch): 0.025232
# \t partial train loss (single batch): 0.026733
# \t partial train loss (single batch): 0.025469
# \t partial train loss (single batch): 0.026028
# \t partial train loss (single batch): 0.025813
# \t partial train loss (single batch): 0.027460
# \t partial train loss (single batch): 0.026645
# \t partial train loss (single batch): 0.025428
# \t partial train loss (single batch): 0.026508
# \t partial train loss (single batch): 0.025940
# \t partial train loss (single batch): 0.026227
# \t partial train loss (single batch): 0.025940
# \t partial train loss (single batch): 0.024848
# \t partial train loss (single batch): 0.025569
# \t partial train loss (single batch): 0.026554
# \t partial train loss (single batch): 0.024777
# \t partial train loss (single batch): 0.025077
# \t partial train loss (single batch): 0.024715
# \t partial train loss (single batch): 0.024848
# \t partial train loss (single batch): 0.025886
# \t partial train loss (single batch): 0.023905
# \t partial train loss (single batch): 0.024392
# \t partial train loss (single batch): 0.027215
# \t partial train loss (single batch): 0.025996
# \t partial train loss (single batch): 0.025365
# \t partial train loss (single batch): 0.024748
# \t partial train loss (single batch): 0.025262
# \t partial train loss (single batch): 0.024763
# \t partial train loss (single batch): 0.024422
# \t partial train loss (single batch): 0.025985
# \t partial train loss (single batch): 0.025317
# \t partial train loss (single batch): 0.024846
# \t partial train loss (single batch): 0.025273
# \t partial train loss (single batch): 0.024699
# \t partial train loss (single batch): 0.024906
# \t partial train loss (single batch): 0.025557
# \t partial train loss (single batch): 0.023894
# \t partial train loss (single batch): 0.024478
# \t partial train loss (single batch): 0.024508
# \n EPOCH 3/30 \t train loss 0.027 \t val loss 0.025
# \t partial train loss (single batch): 0.025769
# \t partial train loss (single batch): 0.024651
# \t partial train loss (single batch): 0.023814
# \t partial train loss (single batch): 0.024486
# \t partial train loss (single batch): 0.024897
# \t partial train loss (single batch): 0.024837
# \t partial train loss (single batch): 0.025050
# \t partial train loss (single batch): 0.026113
# \t partial train loss (single batch): 0.026203
# \t partial train loss (single batch): 0.025086
# \t partial train loss (single batch): 0.024943
# \t partial train loss (single batch): 0.024216
# \t partial train loss (single batch): 0.024948
# \t partial train loss (single batch): 0.024624
# \t partial train loss (single batch): 0.025149
# \t partial train loss (single batch): 0.025463
# \t partial train loss (single batch): 0.026477
# \t partial train loss (single batch): 0.023472
# \t partial train loss (single batch): 0.025523
# \t partial train loss (single batch): 0.025236
# \t partial train loss (single batch): 0.024606
# \t partial train loss (single batch): 0.023920
# \t partial train loss (single batch): 0.025095
# \t partial train loss (single batch): 0.024710
# \t partial train loss (single batch): 0.024227
# \t partial train loss (single batch): 0.026999
# \t partial train loss (single batch): 0.025537
# \t partial train loss (single batch): 0.025226
# \t partial train loss (single batch): 0.024516
# \t partial train loss (single batch): 0.023575
# \t partial train loss (single batch): 0.026387
# \t partial train loss (single batch): 0.024333
# \t partial train loss (single batch): 0.025130
# \t partial train loss (single batch): 0.025468
# \t partial train loss (single batch): 0.024044
# \t partial train loss (single batch): 0.024556
# \t partial train loss (single batch): 0.024574
# \t partial train loss (single batch): 0.025036
# \t partial train loss (single batch): 0.023343
# \t partial train loss (single batch): 0.024547
# \t partial train loss (single batch): 0.024077
# \t partial train loss (single batch): 0.023558
# \t partial train loss (single batch): 0.024170
# \t partial train loss (single batch): 0.023854
# \t partial train loss (single batch): 0.024661
# \t partial train loss (single batch): 0.023738
# \t partial train loss (single batch): 0.023388
# \t partial train loss (single batch): 0.024177
# \t partial train loss (single batch): 0.025027
# \t partial train loss (single batch): 0.024462
# \t partial train loss (single batch): 0.022886
# \t partial train loss (single batch): 0.024162
# \t partial train loss (single batch): 0.022986
# \t partial train loss (single batch): 0.024159
# \t partial train loss (single batch): 0.023648
# \t partial train loss (single batch): 0.023842
# \t partial train loss (single batch): 0.023978
# \t partial train loss (single batch): 0.025433
# \t partial train loss (single batch): 0.023348
# \t partial train loss (single batch): 0.024873
# \t partial train loss (single batch): 0.025075
# \t partial train loss (single batch): 0.023718
# \t partial train loss (single batch): 0.024012
# \t partial train loss (single batch): 0.023764
# \t partial train loss (single batch): 0.025465
# \t partial train loss (single batch): 0.023608
# \t partial train loss (single batch): 0.024953
# \t partial train loss (single batch): 0.024039
# \t partial train loss (single batch): 0.022696
# \t partial train loss (single batch): 0.024414
# \t partial train loss (single batch): 0.025119
# \t partial train loss (single batch): 0.023325
# \t partial train loss (single batch): 0.024191
# \t partial train loss (single batch): 0.025156
# \t partial train loss (single batch): 0.023706
# \t partial train loss (single batch): 0.024243
# \t partial train loss (single batch): 0.025938
# \t partial train loss (single batch): 0.024108
# \t partial train loss (single batch): 0.023099
# \t partial train loss (single batch): 0.025033
# \t partial train loss (single batch): 0.023430
# \t partial train loss (single batch): 0.023608
# \t partial train loss (single batch): 0.024815
# \t partial train loss (single batch): 0.024863
# \t partial train loss (single batch): 0.024242
# \t partial train loss (single batch): 0.023615
# \t partial train loss (single batch): 0.023383
# \t partial train loss (single batch): 0.023868
# \t partial train loss (single batch): 0.023267
# \t partial train loss (single batch): 0.023229
# \t partial train loss (single batch): 0.022778
# \t partial train loss (single batch): 0.022970
# \t partial train loss (single batch): 0.024132
# \t partial train loss (single batch): 0.023423
# \t partial train loss (single batch): 0.024147
# \t partial train loss (single batch): 0.023341
# \t partial train loss (single batch): 0.023942
# \t partial train loss (single batch): 0.024360
# \t partial train loss (single batch): 0.024043
# \t partial train loss (single batch): 0.023979
# \t partial train loss (single batch): 0.022931
# \t partial train loss (single batch): 0.023333
# \t partial train loss (single batch): 0.024179
# \t partial train loss (single batch): 0.024130
# \t partial train loss (single batch): 0.023664
# \t partial train loss (single batch): 0.024240
# \t partial train loss (single batch): 0.024365
# \t partial train loss (single batch): 0.024034
# \t partial train loss (single batch): 0.024720
# \t partial train loss (single batch): 0.023045
# \t partial train loss (single batch): 0.024717
# \t partial train loss (single batch): 0.022866
# \t partial train loss (single batch): 0.024299
# \t partial train loss (single batch): 0.023442
# \t partial train loss (single batch): 0.024291
# \t partial train loss (single batch): 0.023902
# \t partial train loss (single batch): 0.023396
# \t partial train loss (single batch): 0.023940
# \t partial train loss (single batch): 0.023108
# \t partial train loss (single batch): 0.024660
# \t partial train loss (single batch): 0.024399
# \t partial train loss (single batch): 0.022830
# \t partial train loss (single batch): 0.022578
# \t partial train loss (single batch): 0.024167
# \t partial train loss (single batch): 0.023590
# \t partial train loss (single batch): 0.022719
# \t partial train loss (single batch): 0.022316
# \t partial train loss (single batch): 0.024226
# \t partial train loss (single batch): 0.023903
# \t partial train loss (single batch): 0.022789
# \t partial train loss (single batch): 0.023223
# \t partial train loss (single batch): 0.022564
# \t partial train loss (single batch): 0.023743
# \t partial train loss (single batch): 0.023534
# \t partial train loss (single batch): 0.022850
# \t partial train loss (single batch): 0.024678
# \t partial train loss (single batch): 0.023366
# \t partial train loss (single batch): 0.021632
# \t partial train loss (single batch): 0.023837
# \t partial train loss (single batch): 0.024490
# \t partial train loss (single batch): 0.024602
# \t partial train loss (single batch): 0.024026
# \t partial train loss (single batch): 0.023246
# \t partial train loss (single batch): 0.022273
# \t partial train loss (single batch): 0.024287
# \t partial train loss (single batch): 0.023591
# \t partial train loss (single batch): 0.022733
# \t partial train loss (single batch): 0.024593
# \t partial train loss (single batch): 0.022999
# \t partial train loss (single batch): 0.022933
# \t partial train loss (single batch): 0.024597
# \t partial train loss (single batch): 0.023088
# \t partial train loss (single batch): 0.023699
# \t partial train loss (single batch): 0.023594
# \t partial train loss (single batch): 0.024877
# \t partial train loss (single batch): 0.024279
# \t partial train loss (single batch): 0.023310
# \t partial train loss (single batch): 0.023990
# \t partial train loss (single batch): 0.023701
# \t partial train loss (single batch): 0.024171
# \t partial train loss (single batch): 0.023629
# \t partial train loss (single batch): 0.022827
# \t partial train loss (single batch): 0.023314
# \t partial train loss (single batch): 0.024277
# \t partial train loss (single batch): 0.022545
# \t partial train loss (single batch): 0.023037
# \t partial train loss (single batch): 0.022316
# \t partial train loss (single batch): 0.022725
# \t partial train loss (single batch): 0.023793
# \t partial train loss (single batch): 0.021850
# \t partial train loss (single batch): 0.022223
# \t partial train loss (single batch): 0.025301
# \t partial train loss (single batch): 0.023858
# \t partial train loss (single batch): 0.023134
# \t partial train loss (single batch): 0.022765
# \t partial train loss (single batch): 0.023306
# \t partial train loss (single batch): 0.022745
# \t partial train loss (single batch): 0.022305
# \t partial train loss (single batch): 0.024023
# \t partial train loss (single batch): 0.023246
# \t partial train loss (single batch): 0.022941
# \t partial train loss (single batch): 0.023320
# \t partial train loss (single batch): 0.022711
# \t partial train loss (single batch): 0.022947
# \t partial train loss (single batch): 0.023565
# \t partial train loss (single batch): 0.021984
# \t partial train loss (single batch): 0.022436
# \t partial train loss (single batch): 0.022652
# \n EPOCH 4/30 \t train loss 0.024 \t val loss 0.023
# \t partial train loss (single batch): 0.023898
# \t partial train loss (single batch): 0.022821
# \t partial train loss (single batch): 0.021989
# \t partial train loss (single batch): 0.022670
# \t partial train loss (single batch): 0.022961
# \t partial train loss (single batch): 0.022860
# \t partial train loss (single batch): 0.023287
# \t partial train loss (single batch): 0.024183
# \t partial train loss (single batch): 0.024255
# \t partial train loss (single batch): 0.023197
# \t partial train loss (single batch): 0.023237
# \t partial train loss (single batch): 0.022290
# \t partial train loss (single batch): 0.023140
# \t partial train loss (single batch): 0.022950
# \t partial train loss (single batch): 0.023226
# \t partial train loss (single batch): 0.023640
# \t partial train loss (single batch): 0.024702
# \t partial train loss (single batch): 0.021698
# \t partial train loss (single batch): 0.023485
# \t partial train loss (single batch): 0.023370
# \t partial train loss (single batch): 0.022721
# \t partial train loss (single batch): 0.022121
# \t partial train loss (single batch): 0.023431
# \t partial train loss (single batch): 0.022912
# \t partial train loss (single batch): 0.022425
# \t partial train loss (single batch): 0.025398
# \t partial train loss (single batch): 0.023835
# \t partial train loss (single batch): 0.023459
# \t partial train loss (single batch): 0.022748
# \t partial train loss (single batch): 0.021757
# \t partial train loss (single batch): 0.024680
# \t partial train loss (single batch): 0.022665
# \t partial train loss (single batch): 0.023282
# \t partial train loss (single batch): 0.023706
# \t partial train loss (single batch): 0.022391
# \t partial train loss (single batch): 0.022709
# \t partial train loss (single batch): 0.022765
# \t partial train loss (single batch): 0.023371
# \t partial train loss (single batch): 0.021683
# \t partial train loss (single batch): 0.022783
# \t partial train loss (single batch): 0.022297
# \t partial train loss (single batch): 0.021743
# \t partial train loss (single batch): 0.022467
# \t partial train loss (single batch): 0.022309
# \t partial train loss (single batch): 0.023093
# \t partial train loss (single batch): 0.022228
# \t partial train loss (single batch): 0.021703
# \t partial train loss (single batch): 0.022569
# \t partial train loss (single batch): 0.023456
# \t partial train loss (single batch): 0.022870
# \t partial train loss (single batch): 0.021211
# \t partial train loss (single batch): 0.022513
# \t partial train loss (single batch): 0.021275
# \t partial train loss (single batch): 0.022564
# \t partial train loss (single batch): 0.022081
# \t partial train loss (single batch): 0.022272
# \t partial train loss (single batch): 0.022352
# \t partial train loss (single batch): 0.023644
# \t partial train loss (single batch): 0.021765
# \t partial train loss (single batch): 0.023413
# \t partial train loss (single batch): 0.023409
# \t partial train loss (single batch): 0.022153
# \t partial train loss (single batch): 0.022327
# \t partial train loss (single batch): 0.022229
# \t partial train loss (single batch): 0.023767
# \t partial train loss (single batch): 0.022126
# \t partial train loss (single batch): 0.023460
# \t partial train loss (single batch): 0.022470
# \t partial train loss (single batch): 0.021180
# \t partial train loss (single batch): 0.022890
# \t partial train loss (single batch): 0.023593
# \t partial train loss (single batch): 0.021693
# \t partial train loss (single batch): 0.022740
# \t partial train loss (single batch): 0.023786
# \t partial train loss (single batch): 0.022198
# \t partial train loss (single batch): 0.022694
# \t partial train loss (single batch): 0.024479
# \t partial train loss (single batch): 0.022555
# \t partial train loss (single batch): 0.021633
# \t partial train loss (single batch): 0.023587
# \t partial train loss (single batch): 0.022075
# \t partial train loss (single batch): 0.022195
# \t partial train loss (single batch): 0.023286
# \t partial train loss (single batch): 0.023496
# \t partial train loss (single batch): 0.022905
# \t partial train loss (single batch): 0.022166
# \t partial train loss (single batch): 0.021957
# \t partial train loss (single batch): 0.022556
# \t partial train loss (single batch): 0.021950
# \t partial train loss (single batch): 0.021865
# \t partial train loss (single batch): 0.021537
# \t partial train loss (single batch): 0.021626
# \t partial train loss (single batch): 0.022730
# \t partial train loss (single batch): 0.022199
# \t partial train loss (single batch): 0.022739
# \t partial train loss (single batch): 0.022082
# \t partial train loss (single batch): 0.022663
# \t partial train loss (single batch): 0.022986
# \t partial train loss (single batch): 0.022610
# \t partial train loss (single batch): 0.022548
# \t partial train loss (single batch): 0.021628
# \t partial train loss (single batch): 0.022087
# \t partial train loss (single batch): 0.022896
# \t partial train loss (single batch): 0.022837
# \t partial train loss (single batch): 0.022435
# \t partial train loss (single batch): 0.022899
# \t partial train loss (single batch): 0.023118
# \t partial train loss (single batch): 0.022716
# \t partial train loss (single batch): 0.023461
# \t partial train loss (single batch): 0.021788
# \t partial train loss (single batch): 0.023296
# \t partial train loss (single batch): 0.021690
# \t partial train loss (single batch): 0.022968
# \t partial train loss (single batch): 0.022113
# \t partial train loss (single batch): 0.023103
# \t partial train loss (single batch): 0.022546
# \t partial train loss (single batch): 0.022113
# \t partial train loss (single batch): 0.022563
# \t partial train loss (single batch): 0.021896
# \t partial train loss (single batch): 0.023377
# \t partial train loss (single batch): 0.023180
# \t partial train loss (single batch): 0.021484
# \t partial train loss (single batch): 0.021323
# \t partial train loss (single batch): 0.022791
# \t partial train loss (single batch): 0.022307
# \t partial train loss (single batch): 0.021380
# \t partial train loss (single batch): 0.021112
# \t partial train loss (single batch): 0.022903
# \t partial train loss (single batch): 0.022535
# \t partial train loss (single batch): 0.021593
# \t partial train loss (single batch): 0.021949
# \t partial train loss (single batch): 0.021372
# \t partial train loss (single batch): 0.022575
# \t partial train loss (single batch): 0.022336
# \t partial train loss (single batch): 0.021620
# \t partial train loss (single batch): 0.023517
# \t partial train loss (single batch): 0.022163
# \t partial train loss (single batch): 0.020509
# \t partial train loss (single batch): 0.022686
# \t partial train loss (single batch): 0.023272
# \t partial train loss (single batch): 0.023334
# \t partial train loss (single batch): 0.022756
# \t partial train loss (single batch): 0.022008
# \t partial train loss (single batch): 0.021026
# \t partial train loss (single batch): 0.023039
# \t partial train loss (single batch): 0.022327
# \t partial train loss (single batch): 0.021595
# \t partial train loss (single batch): 0.023326
# \t partial train loss (single batch): 0.021829
# \t partial train loss (single batch): 0.021789
# \t partial train loss (single batch): 0.023430
# \t partial train loss (single batch): 0.022073
# \t partial train loss (single batch): 0.022511
# \t partial train loss (single batch): 0.022444
# \t partial train loss (single batch): 0.023743
# \t partial train loss (single batch): 0.022965
# \t partial train loss (single batch): 0.022276
# \t partial train loss (single batch): 0.022892
# \t partial train loss (single batch): 0.022472
# \t partial train loss (single batch): 0.023164
# \t partial train loss (single batch): 0.022605
# \t partial train loss (single batch): 0.021807
# \t partial train loss (single batch): 0.022263
# \t partial train loss (single batch): 0.023125
# \t partial train loss (single batch): 0.021497
# \t partial train loss (single batch): 0.021974
# \t partial train loss (single batch): 0.021192
# \t partial train loss (single batch): 0.021604
# \t partial train loss (single batch): 0.022702
# \t partial train loss (single batch): 0.020769
# \t partial train loss (single batch): 0.021073
# \t partial train loss (single batch): 0.024353
# \t partial train loss (single batch): 0.022728
# \t partial train loss (single batch): 0.021927
# \t partial train loss (single batch): 0.021784
# \t partial train loss (single batch): 0.022323
# \t partial train loss (single batch): 0.021829
# \t partial train loss (single batch): 0.021269
# \t partial train loss (single batch): 0.023071
# \t partial train loss (single batch): 0.022166
# \t partial train loss (single batch): 0.022081
# \t partial train loss (single batch): 0.022270
# \t partial train loss (single batch): 0.021720
# \t partial train loss (single batch): 0.022022
# \t partial train loss (single batch): 0.022495
# \t partial train loss (single batch): 0.020979
# \t partial train loss (single batch): 0.021422
# \t partial train loss (single batch): 0.021649
# \n EPOCH 5/30 \t train loss 0.023 \t val loss 0.022
# \t partial train loss (single batch): 0.022880
# \t partial train loss (single batch): 0.021764
# \t partial train loss (single batch): 0.021036
# \t partial train loss (single batch): 0.021598
# \t partial train loss (single batch): 0.021960
# \t partial train loss (single batch): 0.021814
# \t partial train loss (single batch): 0.022330
# \t partial train loss (single batch): 0.023217
# \t partial train loss (single batch): 0.023212
# \t partial train loss (single batch): 0.022284
# \t partial train loss (single batch): 0.022257
# \t partial train loss (single batch): 0.021341
# \t partial train loss (single batch): 0.022186
# \t partial train loss (single batch): 0.022067
# \t partial train loss (single batch): 0.022279
# \t partial train loss (single batch): 0.022614
# \t partial train loss (single batch): 0.023715
# \t partial train loss (single batch): 0.020796
# \t partial train loss (single batch): 0.022470
# \t partial train loss (single batch): 0.022345
# \t partial train loss (single batch): 0.021746
# \t partial train loss (single batch): 0.021282
# \t partial train loss (single batch): 0.022600
# \t partial train loss (single batch): 0.022017
# \t partial train loss (single batch): 0.021504
# \t partial train loss (single batch): 0.024483
# \t partial train loss (single batch): 0.022960
# \t partial train loss (single batch): 0.022566
# \t partial train loss (single batch): 0.021763
# \t partial train loss (single batch): 0.020872
# \t partial train loss (single batch): 0.023815
# \t partial train loss (single batch): 0.021819
# \t partial train loss (single batch): 0.022283
# \t partial train loss (single batch): 0.022821
# \t partial train loss (single batch): 0.021514
# \t partial train loss (single batch): 0.021759
# \t partial train loss (single batch): 0.021920
# \t partial train loss (single batch): 0.022529
# \t partial train loss (single batch): 0.020803
# \t partial train loss (single batch): 0.021917
# \t partial train loss (single batch): 0.021508
# \t partial train loss (single batch): 0.020810
# \t partial train loss (single batch): 0.021565
# \t partial train loss (single batch): 0.021513
# \t partial train loss (single batch): 0.022242
# \t partial train loss (single batch): 0.021490
# \t partial train loss (single batch): 0.020803
# \t partial train loss (single batch): 0.021703
# \t partial train loss (single batch): 0.022629
# \t partial train loss (single batch): 0.022063
# \t partial train loss (single batch): 0.020289
# \t partial train loss (single batch): 0.021639
# \t partial train loss (single batch): 0.020425
# \t partial train loss (single batch): 0.021674
# \t partial train loss (single batch): 0.021265
# \t partial train loss (single batch): 0.021462
# \t partial train loss (single batch): 0.021520
# \t partial train loss (single batch): 0.022767
# \t partial train loss (single batch): 0.020872
# \t partial train loss (single batch): 0.022589
# \t partial train loss (single batch): 0.022517
# \t partial train loss (single batch): 0.021249
# \t partial train loss (single batch): 0.021469
# \t partial train loss (single batch): 0.021449
# \t partial train loss (single batch): 0.022841
# \t partial train loss (single batch): 0.021348
# \t partial train loss (single batch): 0.022622
# \t partial train loss (single batch): 0.021597
# \t partial train loss (single batch): 0.020368
# \t partial train loss (single batch): 0.022129
# \t partial train loss (single batch): 0.022829
# \t partial train loss (single batch): 0.020812
# \t partial train loss (single batch): 0.021903
# \t partial train loss (single batch): 0.023046
# \t partial train loss (single batch): 0.021410
# ...
# \t partial train loss (single batch): 0.018065
# \t partial train loss (single batch): 0.019018
# \t partial train loss (single batch): 0.018895
# \t partial train loss (single batch): 0.018124
# \t partial train loss (single batch): 0.018623
# \t partial train loss (single batch): 0.018905
# \t partial train loss (single batch): 0.019601
# \t partial train loss (single batch): 0.019071
# \t partial train loss (single batch): 0.017624
# \t partial train loss (single batch): 0.019072
# \t partial train loss (single batch): 0.019913
# \t partial train loss (single batch): 0.019402
# \t partial train loss (single batch): 0.017354
# \t partial train loss (single batch): 0.019008
# \t partial train loss (single batch): 0.017601
# \t partial train loss (single batch): 0.018780
# \t partial train loss (single batch): 0.018688
# \t partial train loss (single batch): 0.019020
# \t partial train loss (single batch): 0.018762
# \t partial train loss (single batch): 0.019818
# \t partial train loss (single batch): 0.018069
# \t partial train loss (single batch): 0.019826
# \t partial train loss (single batch): 0.019456
# \t partial train loss (single batch): 0.018466
# \t partial train loss (single batch): 0.018973
# \t partial train loss (single batch): 0.018692
# \t partial train loss (single batch): 0.019925
# \t partial train loss (single batch): 0.018766
# \t partial train loss (single batch): 0.019824
# \t partial train loss (single batch): 0.018415
# \t partial train loss (single batch): 0.017546
# \t partial train loss (single batch): 0.019697
# \t partial train loss (single batch): 0.020251
# \t partial train loss (single batch): 0.018039
# \t partial train loss (single batch): 0.018784
# \t partial train loss (single batch): 0.020611
# \t partial train loss (single batch): 0.018850
# \t partial train loss (single batch): 0.019063
# \t partial train loss (single batch): 0.020917
# \t partial train loss (single batch): 0.018966
# \t partial train loss (single batch): 0.018584
# \t partial train loss (single batch): 0.020022
# \t partial train loss (single batch): 0.018786
# \t partial train loss (single batch): 0.018899
# \t partial train loss (single batch): 0.019905
# \t partial train loss (single batch): 0.020017
# \t partial train loss (single batch): 0.019625
# \t partial train loss (single batch): 0.018633
# \t partial train loss (single batch): 0.018492
# \t partial train loss (single batch): 0.019436
# \t partial train loss (single batch): 0.018421
# \t partial train loss (single batch): 0.017757
# \t partial train loss (single batch): 0.018500
# \t partial train loss (single batch): 0.018346
# \t partial train loss (single batch): 0.019048
# \t partial train loss (single batch): 0.018812
# \t partial train loss (single batch): 0.019190
# \t partial train loss (single batch): 0.018756
# \t partial train loss (single batch): 0.019203
# \t partial train loss (single batch): 0.019303
# \t partial train loss (single batch): 0.019129
# \t partial train loss (single batch): 0.018839
# \t partial train loss (single batch): 0.018080
# \t partial train loss (single batch): 0.019014
# \t partial train loss (single batch): 0.019386
# \t partial train loss (single batch): 0.019332
# \t partial train loss (single batch): 0.018863
# \t partial train loss (single batch): 0.019319
# \t partial train loss (single batch): 0.019526
# \t partial train loss (single batch): 0.019499
# \t partial train loss (single batch): 0.019839
# \t partial train loss (single batch): 0.018307
# \t partial train loss (single batch): 0.019567
# \t partial train loss (single batch): 0.018309
# \t partial train loss (single batch): 0.019818
# \t partial train loss (single batch): 0.018674
# \t partial train loss (single batch): 0.019739
# \t partial train loss (single batch): 0.019100
# \t partial train loss (single batch): 0.018913
# \t partial train loss (single batch): 0.019188
# \t partial train loss (single batch): 0.018863
# \t partial train loss (single batch): 0.019927
# \t partial train loss (single batch): 0.019997
# \t partial train loss (single batch): 0.018058
# \t partial train loss (single batch): 0.017769
# \t partial train loss (single batch): 0.019201
# \t partial train loss (single batch): 0.018706
# \t partial train loss (single batch): 0.018146
# \t partial train loss (single batch): 0.018046
# \t partial train loss (single batch): 0.019542
# \t partial train loss (single batch): 0.019052
# \t partial train loss (single batch): 0.018459
# \t partial train loss (single batch): 0.018636
# \t partial train loss (single batch): 0.018267
# \t partial train loss (single batch): 0.019252
# \t partial train loss (single batch): 0.018931
# \t partial train loss (single batch): 0.018404
# \t partial train loss (single batch): 0.020225
# \t partial train loss (single batch): 0.018841
# \t partial train loss (single batch): 0.017417
# \t partial train loss (single batch): 0.019216
# \t partial train loss (single batch): 0.020079
# \t partial train loss (single batch): 0.020148
# \t partial train loss (single batch): 0.019375
# \t partial train loss (single batch): 0.018777
# \t partial train loss (single batch): 0.017819
# \t partial train loss (single batch): 0.019722
# \t partial train loss (single batch): 0.019149
# \t partial train loss (single batch): 0.018257
# \t partial train loss (single batch): 0.019995
# \t partial train loss (single batch): 0.018548
# \t partial train loss (single batch): 0.018552
# \t partial train loss (single batch): 0.020450
# \t partial train loss (single batch): 0.018887
# \t partial train loss (single batch): 0.018853
# \t partial train loss (single batch): 0.019222
# \t partial train loss (single batch): 0.020107
# \t partial train loss (single batch): 0.019401
# \t partial train loss (single batch): 0.019198
# \t partial train loss (single batch): 0.019331
# \t partial train loss (single batch): 0.018980
# \t partial train loss (single batch): 0.019843
# \t partial train loss (single batch): 0.018925
# \t partial train loss (single batch): 0.018403
# \t partial train loss (single batch): 0.018863
# \t partial train loss (single batch): 0.019390
# \t partial train loss (single batch): 0.018049
# \t partial train loss (single batch): 0.018573
# \t partial train loss (single batch): 0.017914
# \t partial train loss (single batch): 0.017991
# \t partial train loss (single batch): 0.019343
# \t partial train loss (single batch): 0.017411
# \t partial train loss (single batch): 0.018014
# \t partial train loss (single batch): 0.020944
# \t partial train loss (single batch): 0.019362
# \t partial train loss (single batch): 0.018652
# \t partial train loss (single batch): 0.018581
# \t partial train loss (single batch): 0.019236
# \t partial train loss (single batch): 0.018835
# \t partial train loss (single batch): 0.018214
# \t partial train loss (single batch): 0.019872
# \t partial train loss (single batch): 0.019212
# \t partial train loss (single batch): 0.018924
# \t partial train loss (single batch): 0.019347
# \t partial train loss (single batch): 0.018852
# \t partial train loss (single batch): 0.018682
# \t partial train loss (single batch): 0.019259
# \t partial train loss (single batch): 0.018005
# \t partial train loss (single batch): 0.017950
# \t partial train loss (single batch): 0.018950
# \n EPOCH 29/30 \t train loss 0.019 \t val loss 0.019
# \t partial train loss (single batch): 0.019399
# \t partial train loss (single batch): 0.018648
# \t partial train loss (single batch): 0.018027
# \t partial train loss (single batch): 0.018455
# \t partial train loss (single batch): 0.018746
# \t partial train loss (single batch): 0.018707
# \t partial train loss (single batch): 0.018993
# \t partial train loss (single batch): 0.019844
# \t partial train loss (single batch): 0.019739
# \t partial train loss (single batch): 0.019391
# \t partial train loss (single batch): 0.019335
# \t partial train loss (single batch): 0.018161
# \t partial train loss (single batch): 0.019034
# \t partial train loss (single batch): 0.019126
# \t partial train loss (single batch): 0.019147
# \t partial train loss (single batch): 0.019295
# \t partial train loss (single batch): 0.020766
# \t partial train loss (single batch): 0.017646
# \t partial train loss (single batch): 0.019326
# \t partial train loss (single batch): 0.019181
# \t partial train loss (single batch): 0.018633
# \t partial train loss (single batch): 0.018347
# \t partial train loss (single batch): 0.019943
# \t partial train loss (single batch): 0.018924
# \t partial train loss (single batch): 0.018607
# \t partial train loss (single batch): 0.021581
# \t partial train loss (single batch): 0.019909
# \t partial train loss (single batch): 0.019539
# \t partial train loss (single batch): 0.018548
# \t partial train loss (single batch): 0.017814
# \t partial train loss (single batch): 0.020891
# \t partial train loss (single batch): 0.019291
# \t partial train loss (single batch): 0.019194
# \t partial train loss (single batch): 0.019889
# \t partial train loss (single batch): 0.018512
# \t partial train loss (single batch): 0.018860
# \t partial train loss (single batch): 0.018779
# \t partial train loss (single batch): 0.019404
# \t partial train loss (single batch): 0.018024
# \t partial train loss (single batch): 0.018976
# \t partial train loss (single batch): 0.018862
# \t partial train loss (single batch): 0.018086
# \t partial train loss (single batch): 0.018584
# \t partial train loss (single batch): 0.018888
# \t partial train loss (single batch): 0.019553
# \t partial train loss (single batch): 0.019034
# \t partial train loss (single batch): 0.017582
# \t partial train loss (single batch): 0.019018
# \t partial train loss (single batch): 0.019870
# \t partial train loss (single batch): 0.019358
# \t partial train loss (single batch): 0.017303
# \t partial train loss (single batch): 0.018972
# \t partial train loss (single batch): 0.017575
# \t partial train loss (single batch): 0.018722
# \t partial train loss (single batch): 0.018650
# \t partial train loss (single batch): 0.018997
# \t partial train loss (single batch): 0.018747
# \t partial train loss (single batch): 0.019837
# \t partial train loss (single batch): 0.018058
# \t partial train loss (single batch): 0.019795
# \t partial train loss (single batch): 0.019466
# \t partial train loss (single batch): 0.018433
# \t partial train loss (single batch): 0.018964
# \t partial train loss (single batch): 0.018660
# \t partial train loss (single batch): 0.019862
# \t partial train loss (single batch): 0.018761
# \t partial train loss (single batch): 0.019759
# \t partial train loss (single batch): 0.018377
# \t partial train loss (single batch): 0.017494
# \t partial train loss (single batch): 0.019639
# \t partial train loss (single batch): 0.020218
# \t partial train loss (single batch): 0.018035
# \t partial train loss (single batch): 0.018719
# \t partial train loss (single batch): 0.020547
# \t partial train loss (single batch): 0.018836
# \t partial train loss (single batch): 0.019023
# \t partial train loss (single batch): 0.020885
# \t partial train loss (single batch): 0.018952
# \t partial train loss (single batch): 0.018577
# \t partial train loss (single batch): 0.020002
# \t partial train loss (single batch): 0.018774
# \t partial train loss (single batch): 0.018868
# \t partial train loss (single batch): 0.019861
# \t partial train loss (single batch): 0.019986
# \t partial train loss (single batch): 0.019602
# \t partial train loss (single batch): 0.018605
# \t partial train loss (single batch): 0.018463
# \t partial train loss (single batch): 0.019435
# \t partial train loss (single batch): 0.018380
# \t partial train loss (single batch): 0.017725
# \t partial train loss (single batch): 0.018454
# \t partial train loss (single batch): 0.018294
# \t partial train loss (single batch): 0.019023
# \t partial train loss (single batch): 0.018777
# \t partial train loss (single batch): 0.019142
# \t partial train loss (single batch): 0.018711
# \t partial train loss (single batch): 0.019153
# \t partial train loss (single batch): 0.019255
# \t partial train loss (single batch): 0.019077
# \t partial train loss (single batch): 0.018809
# \t partial train loss (single batch): 0.018030
# \t partial train loss (single batch): 0.018960
# \t partial train loss (single batch): 0.019325
# \t partial train loss (single batch): 0.019300
# \t partial train loss (single batch): 0.018823
# \t partial train loss (single batch): 0.019253
# \t partial train loss (single batch): 0.019462
# \t partial train loss (single batch): 0.019486
# \t partial train loss (single batch): 0.019807
# \t partial train loss (single batch): 0.018278
# \t partial train loss (single batch): 0.019558
# \t partial train loss (single batch): 0.018294
# \t partial train loss (single batch): 0.019840
# \t partial train loss (single batch): 0.018641
# \t partial train loss (single batch): 0.019716
# \t partial train loss (single batch): 0.019103
# \t partial train loss (single batch): 0.018909
# \t partial train loss (single batch): 0.019148
# \t partial train loss (single batch): 0.018863
# \t partial train loss (single batch): 0.019885
# \t partial train loss (single batch): 0.019997
# \t partial train loss (single batch): 0.018040
# \t partial train loss (single batch): 0.017720
# \t partial train loss (single batch): 0.019140
# \t partial train loss (single batch): 0.018682
# \t partial train loss (single batch): 0.018122
# \t partial train loss (single batch): 0.018022
# \t partial train loss (single batch): 0.019508
# \t partial train loss (single batch): 0.019017
# \t partial train loss (single batch): 0.018450
# \t partial train loss (single batch): 0.018581
# \t partial train loss (single batch): 0.018275
# \t partial train loss (single batch): 0.019201
# \t partial train loss (single batch): 0.018891
# \t partial train loss (single batch): 0.018372
# \t partial train loss (single batch): 0.020204
# \t partial train loss (single batch): 0.018789
# \t partial train loss (single batch): 0.017381
# \t partial train loss (single batch): 0.019173
# \t partial train loss (single batch): 0.020042
# \t partial train loss (single batch): 0.020117
# \t partial train loss (single batch): 0.019358
# \t partial train loss (single batch): 0.018725
# \t partial train loss (single batch): 0.017775
# \t partial train loss (single batch): 0.019675
# \t partial train loss (single batch): 0.019113
# \t partial train loss (single batch): 0.018221
# \t partial train loss (single batch): 0.019954
# \t partial train loss (single batch): 0.018515
# \t partial train loss (single batch): 0.018515
# \t partial train loss (single batch): 0.020451
# \t partial train loss (single batch): 0.018830
# \t partial train loss (single batch): 0.018834
# \t partial train loss (single batch): 0.019196
# \t partial train loss (single batch): 0.020063
# \t partial train loss (single batch): 0.019358
# \t partial train loss (single batch): 0.019181
# \t partial train loss (single batch): 0.019286
# \t partial train loss (single batch): 0.018963
# \t partial train loss (single batch): 0.019843
# \t partial train loss (single batch): 0.018898
# \t partial train loss (single batch): 0.018379
# \t partial train loss (single batch): 0.018837
# \t partial train loss (single batch): 0.019346
# \t partial train loss (single batch): 0.018058
# \t partial train loss (single batch): 0.018556
# \t partial train loss (single batch): 0.017875
# \t partial train loss (single batch): 0.017944
# \t partial train loss (single batch): 0.019358
# \t partial train loss (single batch): 0.017377
# \t partial train loss (single batch): 0.017989
# \t partial train loss (single batch): 0.020994
# \t partial train loss (single batch): 0.019311
# \t partial train loss (single batch): 0.018632
# \t partial train loss (single batch): 0.018581
# \t partial train loss (single batch): 0.019203
# \t partial train loss (single batch): 0.018813
# \t partial train loss (single batch): 0.018209
# \t partial train loss (single batch): 0.019867
# \t partial train loss (single batch): 0.019187
# \t partial train loss (single batch): 0.018912
# \t partial train loss (single batch): 0.019312
# \t partial train loss (single batch): 0.018827
# \t partial train loss (single batch): 0.018651
# \t partial train loss (single batch): 0.019221
# \t partial train loss (single batch): 0.017990
# \t partial train loss (single batch): 0.017896
# \t partial train loss (single batch): 0.018915
# \n EPOCH 30/30 \t train loss 0.019 \t val loss 0.019

# %%
test_epoch(encoder,decoder,device,test_loader,loss_fn).item()
# Out:
# 0.019106073305010796

# %%
# Train and validation loss

plt.figure(figsize=(7,5))
plt.semilogy(history['train_loss'], label='Train')
plt.semilogy(history['val_loss'], label='Valid')
plt.xlabel('Epoch')
plt.ylabel('Average Loss')
#plt.grid()
plt.legend()
#plt.title('loss')
plt.show()
