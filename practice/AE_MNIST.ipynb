# %%
import os
import random
from tqdm import tqdm

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import plotly.express as px
import torchvision
import torch
from torchvision import transforms
from torch.utils.data import DataLoader,random_split
from torch import nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import transforms, datasets

# %%
data_dir = 'data'

train_dataset = torchvision.datasets.MNIST(data_dir, train=True, download=True)
test_dataset  = torchvision.datasets.MNIST(data_dir, train=False, download=True)

print(train_dataset)
type(train_dataset)
# Out:
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 55.4MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 1.76MB/s]
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 14.3MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 8.31MB/s]
# Dataset MNIST
#     Number of datapoints: 60000
#     Root location: data
#     Split: Train
# torchvision.datasets.mnist.MNIST

# %%
fig, axs = plt.subplots(5, 5, figsize=(6,6))
for ax in axs.flatten():
    img, label = random.choice(train_dataset)
    ax.imshow(np.array(img), cmap='gist_gray')
    ax.set_title('Label: %d' % label)
    ax.set_xticks([])
    ax.set_yticks([])
plt.tight_layout()

# %%
# data to tensors
train_transform = transforms.Compose([
    transforms.ToTensor(),
])
test_transform = transforms.Compose([
    transforms.ToTensor(),
])

# Set the train transform
train_dataset.transform = train_transform
# Set the test transform
test_dataset.transform = test_transform

# %%
m=len(train_dataset)
train_data, val_data = random_split(train_dataset, [int(len(train_dataset)*0.8), int(m*0.2)])

# %%
batch_size=256

train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size)
valid_loader = torch.utils.data.DataLoader(val_data, batch_size=batch_size)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size,shuffle=True)

# %%
class Encoder(nn.Module):
    def __init__(self, encoded_space_dim):
        super().__init__()

        # Convolutional section
        self.encoder_cnn = nn.Sequential(
            nn.Conv2d(1, 8, 3, stride=2, padding=1),
            nn.ReLU(True),
            nn.Conv2d(8, 16, 3, stride=2, padding=1),
            nn.BatchNorm2d(16),
            nn.ReLU(True),
            nn.Conv2d(16, 32, 3, stride=2, padding=0),
            nn.ReLU(True)
        )

        # Flatten layer
        self.flatten = nn.Flatten(start_dim=1)

        # Linear section
        self.encoder_lin = nn.Sequential(
            nn.Linear(3 * 3 * 32, 128),
            nn.ReLU(True),
            nn.Linear(128, encoded_space_dim)
        )

    def forward(self, x):
        x = self.encoder_cnn(x)
        x = self.flatten(x)
        x = self.encoder_lin(x)
        return x

# %%
class Decoder(nn.Module):
    def __init__(self, encoded_space_dim, fc2_input_dim=128):
        super().__init__()

        # Linear section
        self.decoder_lin = nn.Sequential(
            nn.Linear(encoded_space_dim, 128),
            nn.ReLU(True),
            nn.Linear(128, 7 * 7 * 16),  # Змінено для 7x7x16
            nn.ReLU(True)
        )

        self.unflatten = nn.Unflatten(dim=1, unflattened_size=(16, 7, 7))

        self.decoder_conv = nn.Sequential(
            nn.ConvTranspose2d(16, 8, 4, stride=2, padding=1),  # 7x7 -> 14x14
            nn.BatchNorm2d(8),
            nn.ReLU(True),
            nn.ConvTranspose2d(8, 1, 4, stride=2, padding=1)  # 14x14 -> 28x28
        )

    def forward(self, x):
        x = self.decoder_lin(x)
        x = self.unflatten(x)
        x = self.decoder_conv(x)
        x = torch.sigmoid(x)
        return x

# %%
# Set the random seed for reproducible results
torch.manual_seed(42)

# Initialize the two networks
encoded_space_dim = 4  # Розмір закодованого простору
encoder = Encoder(encoded_space_dim=encoded_space_dim)
decoder = Decoder(encoded_space_dim=encoded_space_dim)

# %%
img, _ = test_dataset[0]
img = img.unsqueeze(0) # Add the batch dimension in the first axis
print('Original image shape:', img.shape)

# Encode the image
img_enc = encoder(img)
print('Encoded image shape:', img_enc.shape)

# Decode the image
dec_img = decoder(img_enc)
print('Decoded image shape:', dec_img.shape)
# Out:
# Original image shape: torch.Size([1, 1, 28, 28])
# Encoded image shape: torch.Size([1, 4])
# Decoded image shape: torch.Size([1, 1, 28, 28])

# %%
# Define the loss function
loss_fn = torch.nn.MSELoss()

# Define an optimizer (both for the encoder and the decoder!)
lr= 0.001

params_to_optimize = [
    {'params': encoder.parameters()},
    {'params': decoder.parameters()}
]

optim = torch.optim.Adam(params_to_optimize, lr=lr, weight_decay=1e-05)

# Check if the GPU is available
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
print(f'Selected device: {device}')

# Move both the encoder and the decoder to the selected device
encoder.to(device)
# Out:
# Selected device: cuda
# Encoder(
#   (encoder_cnn): Sequential(
#     (0): Conv2d(1, 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(8, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (3): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (4): ReLU(inplace=True)
#     (5): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2))
#     (6): ReLU(inplace=True)
#   )
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (encoder_lin): Sequential(
#     (0): Linear(in_features=288, out_features=128, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Linear(in_features=128, out_features=4, bias=True)
#   )
# )

# %%
decoder.to(device)
# Out:
# Decoder(
#   (decoder_lin): Sequential(
#     (0): Linear(in_features=4, out_features=128, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Linear(in_features=128, out_features=784, bias=True)
#     (3): ReLU(inplace=True)
#   )
#   (unflatten): Unflatten(dim=1, unflattened_size=(16, 7, 7))
#   (decoder_conv): Sequential(
#     (0): ConvTranspose2d(16, 8, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (1): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): ConvTranspose2d(8, 1, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   )
# )

# %%
def train_epoch(encoder, decoder, device, dataloader, loss_fn, optimizer):
    # Set train mode for both the encoder and the decoder
    encoder.train()
    decoder.train()
    train_loss = []
    # Iterate the dataloader (we do not need the label values, this is unsupervised learning)
    for image_batch, _ in dataloader: # with "_" we just ignore the labels (the second element of the dataloader tuple)
        # Move tensor to the proper device
        image_batch = image_batch.to(device)
        # Encode data
        encoded_data = encoder(image_batch)
        # Decode data
        decoded_data = decoder(encoded_data)
        # Evaluate loss
        loss = loss_fn(decoded_data, image_batch)
        # Backward pass
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        # Print batch loss
        print('\\t partial train loss (single batch): %f' % (loss.data))
        train_loss.append(loss.detach().cpu().numpy())

    return np.mean(train_loss)
def test_epoch(encoder, decoder, device, dataloader, loss_fn):
    # Set evaluation mode for encoder and decoder
    encoder.eval()
    decoder.eval()
    with torch.no_grad(): # No need to track the gradients
        # Define the lists to store the outputs for each batch
        conc_out = []
        conc_label = []
        for image_batch, _ in dataloader:
            # Move tensor to the proper device
            image_batch = image_batch.to(device)
            # Encode data
            encoded_data = encoder(image_batch)
            # Decode data
            decoded_data = decoder(encoded_data)
            # Append the network output and the original image to the lists
            conc_out.append(decoded_data.cpu())
            conc_label.append(image_batch.cpu())
        # Create a single tensor with all the values in the lists
        conc_out = torch.cat(conc_out)
        conc_label = torch.cat(conc_label)
        # Evaluate global loss
        val_loss = loss_fn(conc_out, conc_label)
    return val_loss.data

# %%
def plot_ae_outputs(encoder,decoder,n=5):
    plt.figure(figsize=(10,4.5))
    for i in range(n):
        ax = plt.subplot(2,n,i+1)
        img = test_dataset[i][0].unsqueeze(0).to(device)
        encoder.eval()
        decoder.eval()
        with torch.no_grad():
            rec_img  = decoder(encoder(img))
        plt.imshow(img.cpu().squeeze().numpy(), cmap='gist_gray')
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
        if i == n//2:
            ax.set_title('Original images')
        ax = plt.subplot(2, n, i + 1 + n)
        plt.imshow(rec_img.cpu().squeeze().numpy(), cmap='gist_gray')
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
        if i == n//2:
            ax.set_title('Reconstructed images')
    plt.show()

# %%
num_epochs = 20
history={'train_loss':[],'val_loss':[]}

for epoch in range(num_epochs):
    train_loss = train_epoch(encoder,decoder,device,train_loader,loss_fn,optim)
    val_loss = test_epoch(encoder,decoder,device,valid_loader,loss_fn)

    print('\\n EPOCH {}/{} \\t train loss {:.3f} \\t val loss {:.3f}'.format(epoch + 1, num_epochs,train_loss,val_loss))

    history['train_loss'].append(train_loss)
    history['val_loss'].append(val_loss)
    plot_ae_outputs(encoder,decoder,n=5)
# Out:
# \t partial train loss (single batch): 0.332615
# \t partial train loss (single batch): 0.321910
# \t partial train loss (single batch): 0.313491
# \t partial train loss (single batch): 0.305733
# \t partial train loss (single batch): 0.298113
# \t partial train loss (single batch): 0.293457
# \t partial train loss (single batch): 0.287602
# \t partial train loss (single batch): 0.283783
# \t partial train loss (single batch): 0.278221
# \t partial train loss (single batch): 0.275803
# \t partial train loss (single batch): 0.272080
# \t partial train loss (single batch): 0.267444
# \t partial train loss (single batch): 0.263263
# \t partial train loss (single batch): 0.259739
# \t partial train loss (single batch): 0.257493
# \t partial train loss (single batch): 0.253879
# \t partial train loss (single batch): 0.251745
# \t partial train loss (single batch): 0.248381
# \t partial train loss (single batch): 0.245501
# \t partial train loss (single batch): 0.241909
# \t partial train loss (single batch): 0.239346
# \t partial train loss (single batch): 0.236934
# \t partial train loss (single batch): 0.234360
# \t partial train loss (single batch): 0.231272
# \t partial train loss (single batch): 0.228649
# \t partial train loss (single batch): 0.226037
# \t partial train loss (single batch): 0.223755
# \t partial train loss (single batch): 0.221171
# \t partial train loss (single batch): 0.219455
# \t partial train loss (single batch): 0.216448
# \t partial train loss (single batch): 0.214314
# \t partial train loss (single batch): 0.212261
# \t partial train loss (single batch): 0.209670
# \t partial train loss (single batch): 0.208459
# \t partial train loss (single batch): 0.206120
# \t partial train loss (single batch): 0.203529
# \t partial train loss (single batch): 0.201334
# \t partial train loss (single batch): 0.199254
# \t partial train loss (single batch): 0.197019
# \t partial train loss (single batch): 0.194428
# \t partial train loss (single batch): 0.192674
# \t partial train loss (single batch): 0.190634
# \t partial train loss (single batch): 0.188931
# \t partial train loss (single batch): 0.186595
# \t partial train loss (single batch): 0.184308
# \t partial train loss (single batch): 0.183153
# \t partial train loss (single batch): 0.180539
# \t partial train loss (single batch): 0.178542
# \t partial train loss (single batch): 0.176979
# \t partial train loss (single batch): 0.175462
# \t partial train loss (single batch): 0.173316
# \t partial train loss (single batch): 0.171258
# \t partial train loss (single batch): 0.170101
# \t partial train loss (single batch): 0.167825
# \t partial train loss (single batch): 0.165785
# \t partial train loss (single batch): 0.164919
# \t partial train loss (single batch): 0.162298
# \t partial train loss (single batch): 0.160682
# \t partial train loss (single batch): 0.159465
# \t partial train loss (single batch): 0.157238
# \t partial train loss (single batch): 0.155911
# \t partial train loss (single batch): 0.154612
# \t partial train loss (single batch): 0.152406
# \t partial train loss (single batch): 0.151175
# \t partial train loss (single batch): 0.150124
# \t partial train loss (single batch): 0.148911
# \t partial train loss (single batch): 0.146638
# \t partial train loss (single batch): 0.144981
# \t partial train loss (single batch): 0.143424
# \t partial train loss (single batch): 0.142145
# \t partial train loss (single batch): 0.140702
# \t partial train loss (single batch): 0.138431
# \t partial train loss (single batch): 0.137397
# \t partial train loss (single batch): 0.135556
# \t partial train loss (single batch): 0.134670
# \t partial train loss (single batch): 0.132834
# \t partial train loss (single batch): 0.132079
# \t partial train loss (single batch): 0.129992
# \t partial train loss (single batch): 0.129743
# \t partial train loss (single batch): 0.128690
# \t partial train loss (single batch): 0.126439
# \t partial train loss (single batch): 0.125515
# \t partial train loss (single batch): 0.123619
# \t partial train loss (single batch): 0.123192
# \t partial train loss (single batch): 0.121908
# \t partial train loss (single batch): 0.120731
# \t partial train loss (single batch): 0.119271
# \t partial train loss (single batch): 0.118077
# \t partial train loss (single batch): 0.117591
# \t partial train loss (single batch): 0.114981
# \t partial train loss (single batch): 0.115057
# \t partial train loss (single batch): 0.114636
# \t partial train loss (single batch): 0.112429
# \t partial train loss (single batch): 0.112506
# \t partial train loss (single batch): 0.110475
# \t partial train loss (single batch): 0.109624
# \t partial train loss (single batch): 0.109111
# \t partial train loss (single batch): 0.107542
# \t partial train loss (single batch): 0.106393
# \t partial train loss (single batch): 0.106060
# \t partial train loss (single batch): 0.105491
# \t partial train loss (single batch): 0.103054
# \t partial train loss (single batch): 0.102784
# \t partial train loss (single batch): 0.102490
# \t partial train loss (single batch): 0.101483
# \t partial train loss (single batch): 0.100320
# \t partial train loss (single batch): 0.100110
# \t partial train loss (single batch): 0.098403
# \t partial train loss (single batch): 0.097856
# \t partial train loss (single batch): 0.097365
# \t partial train loss (single batch): 0.096384
# \t partial train loss (single batch): 0.094649
# \t partial train loss (single batch): 0.093638
# \t partial train loss (single batch): 0.094580
# \t partial train loss (single batch): 0.093483
# \t partial train loss (single batch): 0.092412
# \t partial train loss (single batch): 0.092298
# \t partial train loss (single batch): 0.090512
# \t partial train loss (single batch): 0.090049
# \t partial train loss (single batch): 0.090358
# \t partial train loss (single batch): 0.087717
# \t partial train loss (single batch): 0.088133
# \t partial train loss (single batch): 0.087828
# \t partial train loss (single batch): 0.086324
# \t partial train loss (single batch): 0.086325
# \t partial train loss (single batch): 0.085230
# \t partial train loss (single batch): 0.084304
# \t partial train loss (single batch): 0.083358
# \t partial train loss (single batch): 0.083552
# \t partial train loss (single batch): 0.082286
# \t partial train loss (single batch): 0.081822
# \t partial train loss (single batch): 0.081091
# \t partial train loss (single batch): 0.081230
# \t partial train loss (single batch): 0.079911
# \t partial train loss (single batch): 0.080579
# \t partial train loss (single batch): 0.080319
# \t partial train loss (single batch): 0.079792
# \t partial train loss (single batch): 0.078318
# \t partial train loss (single batch): 0.078140
# \t partial train loss (single batch): 0.077896
# \t partial train loss (single batch): 0.076355
# \t partial train loss (single batch): 0.076003
# \t partial train loss (single batch): 0.076380
# \t partial train loss (single batch): 0.076159
# \t partial train loss (single batch): 0.074903
# \t partial train loss (single batch): 0.075728
# \t partial train loss (single batch): 0.073756
# \t partial train loss (single batch): 0.074839
# \t partial train loss (single batch): 0.073172
# \t partial train loss (single batch): 0.072510
# \t partial train loss (single batch): 0.073914
# \t partial train loss (single batch): 0.073697
# \t partial train loss (single batch): 0.071296
# \t partial train loss (single batch): 0.071450
# \t partial train loss (single batch): 0.072188
# \t partial train loss (single batch): 0.070131
# \t partial train loss (single batch): 0.069996
# \t partial train loss (single batch): 0.070806
# \t partial train loss (single batch): 0.069311
# \t partial train loss (single batch): 0.070339
# \t partial train loss (single batch): 0.069924
# \t partial train loss (single batch): 0.068380
# \t partial train loss (single batch): 0.067926
# \t partial train loss (single batch): 0.068435
# \t partial train loss (single batch): 0.067613
# \t partial train loss (single batch): 0.067715
# \t partial train loss (single batch): 0.067445
# \t partial train loss (single batch): 0.066589
# \t partial train loss (single batch): 0.066776
# \t partial train loss (single batch): 0.066690
# \t partial train loss (single batch): 0.065757
# \t partial train loss (single batch): 0.065586
# \t partial train loss (single batch): 0.065101
# \t partial train loss (single batch): 0.064471
# \t partial train loss (single batch): 0.064517
# \t partial train loss (single batch): 0.063997
# \t partial train loss (single batch): 0.063883
# \t partial train loss (single batch): 0.063225
# \t partial train loss (single batch): 0.063128
# \t partial train loss (single batch): 0.062315
# \t partial train loss (single batch): 0.061915
# \t partial train loss (single batch): 0.062357
# \t partial train loss (single batch): 0.061476
# \t partial train loss (single batch): 0.062861
# \t partial train loss (single batch): 0.061045
# \t partial train loss (single batch): 0.061039
# \t partial train loss (single batch): 0.060610
# \t partial train loss (single batch): 0.060772
# \n EPOCH 1/20 \t train loss 0.135 \t val loss 0.061
# \t partial train loss (single batch): 0.061085
# \t partial train loss (single batch): 0.059962
# \t partial train loss (single batch): 0.060248
# \t partial train loss (single batch): 0.059784
# \t partial train loss (single batch): 0.060963
# \t partial train loss (single batch): 0.060235
# \t partial train loss (single batch): 0.059963
# \t partial train loss (single batch): 0.059989
# \t partial train loss (single batch): 0.059906
# \t partial train loss (single batch): 0.058415
# \t partial train loss (single batch): 0.057540
# \t partial train loss (single batch): 0.058883
# \t partial train loss (single batch): 0.059189
# \t partial train loss (single batch): 0.058950
# \t partial train loss (single batch): 0.058465
# \t partial train loss (single batch): 0.058367
# \t partial train loss (single batch): 0.056356
# \t partial train loss (single batch): 0.057429
# \t partial train loss (single batch): 0.056284
# \t partial train loss (single batch): 0.058017
# \t partial train loss (single batch): 0.056975
# \t partial train loss (single batch): 0.057519
# \t partial train loss (single batch): 0.056708
# \t partial train loss (single batch): 0.055557
# \t partial train loss (single batch): 0.056166
# \t partial train loss (single batch): 0.055847
# \t partial train loss (single batch): 0.056072
# \t partial train loss (single batch): 0.055190
# \t partial train loss (single batch): 0.055942
# \t partial train loss (single batch): 0.056002
# \t partial train loss (single batch): 0.055116
# \t partial train loss (single batch): 0.054933
# \t partial train loss (single batch): 0.055341
# \t partial train loss (single batch): 0.054186
# \t partial train loss (single batch): 0.053902
# \t partial train loss (single batch): 0.053831
# \t partial train loss (single batch): 0.053804
# \t partial train loss (single batch): 0.054750
# \t partial train loss (single batch): 0.054201
# \t partial train loss (single batch): 0.053344
# \t partial train loss (single batch): 0.053807
# \t partial train loss (single batch): 0.053098
# \t partial train loss (single batch): 0.052951
# \t partial train loss (single batch): 0.053888
# \t partial train loss (single batch): 0.052975
# \t partial train loss (single batch): 0.053273
# \t partial train loss (single batch): 0.053527
# \t partial train loss (single batch): 0.053842
# \t partial train loss (single batch): 0.050778
# \t partial train loss (single batch): 0.052350
# \t partial train loss (single batch): 0.051933
# \t partial train loss (single batch): 0.052981
# \t partial train loss (single batch): 0.051826
# \t partial train loss (single batch): 0.051205
# \t partial train loss (single batch): 0.053614
# \t partial train loss (single batch): 0.051635
# \t partial train loss (single batch): 0.051504
# \t partial train loss (single batch): 0.051074
# \t partial train loss (single batch): 0.050974
# \t partial train loss (single batch): 0.049894
# \t partial train loss (single batch): 0.051658
# \t partial train loss (single batch): 0.051069
# \t partial train loss (single batch): 0.049454
# \t partial train loss (single batch): 0.050373
# \t partial train loss (single batch): 0.050589
# \t partial train loss (single batch): 0.052722
# \t partial train loss (single batch): 0.051037
# \t partial train loss (single batch): 0.050326
# \t partial train loss (single batch): 0.050375
# \t partial train loss (single batch): 0.049201
# \t partial train loss (single batch): 0.049607
# \t partial train loss (single batch): 0.048314
# \t partial train loss (single batch): 0.048975
# \t partial train loss (single batch): 0.049433
# \t partial train loss (single batch): 0.049056
# \t partial train loss (single batch): 0.048495
# \t partial train loss (single batch): 0.049452
# \t partial train loss (single batch): 0.047543
# \t partial train loss (single batch): 0.049751
# \t partial train loss (single batch): 0.049147
# \t partial train loss (single batch): 0.047564
# \t partial train loss (single batch): 0.048030
# \t partial train loss (single batch): 0.048197
# \t partial train loss (single batch): 0.049243
# \t partial train loss (single batch): 0.048272
# \t partial train loss (single batch): 0.048982
# \t partial train loss (single batch): 0.048909
# \t partial train loss (single batch): 0.047004
# \t partial train loss (single batch): 0.047969
# \t partial train loss (single batch): 0.046686
# \t partial train loss (single batch): 0.048533
# \t partial train loss (single batch): 0.048826
# \t partial train loss (single batch): 0.047311
# \t partial train loss (single batch): 0.048547
# \t partial train loss (single batch): 0.046452
# \t partial train loss (single batch): 0.047488
# \t partial train loss (single batch): 0.047790
# \t partial train loss (single batch): 0.047003
# \t partial train loss (single batch): 0.046889
# \t partial train loss (single batch): 0.046718
# \t partial train loss (single batch): 0.046616
# \t partial train loss (single batch): 0.045776
# \t partial train loss (single batch): 0.046153
# \t partial train loss (single batch): 0.046734
# \t partial train loss (single batch): 0.046735
# \t partial train loss (single batch): 0.046075
# \t partial train loss (single batch): 0.046355
# \t partial train loss (single batch): 0.045811
# \t partial train loss (single batch): 0.045288
# \t partial train loss (single batch): 0.046570
# \t partial train loss (single batch): 0.045830
# \t partial train loss (single batch): 0.044574
# \t partial train loss (single batch): 0.045169
# \t partial train loss (single batch): 0.047050
# \t partial train loss (single batch): 0.045463
# \t partial train loss (single batch): 0.046347
# \t partial train loss (single batch): 0.046496
# \t partial train loss (single batch): 0.044847
# \t partial train loss (single batch): 0.045381
# \t partial train loss (single batch): 0.046331
# \t partial train loss (single batch): 0.042812
# \t partial train loss (single batch): 0.044505
# \t partial train loss (single batch): 0.045006
# \t partial train loss (single batch): 0.044823
# \t partial train loss (single batch): 0.044541
# \t partial train loss (single batch): 0.044586
# \t partial train loss (single batch): 0.044564
# \t partial train loss (single batch): 0.043298
# \t partial train loss (single batch): 0.044268
# \t partial train loss (single batch): 0.043822
# \t partial train loss (single batch): 0.043759
# \t partial train loss (single batch): 0.043050
# \t partial train loss (single batch): 0.042826
# \t partial train loss (single batch): 0.042565
# \t partial train loss (single batch): 0.043767
# \t partial train loss (single batch): 0.044711
# \t partial train loss (single batch): 0.044752
# \t partial train loss (single batch): 0.043030
# \t partial train loss (single batch): 0.043501
# \t partial train loss (single batch): 0.043574
# \t partial train loss (single batch): 0.042374
# \t partial train loss (single batch): 0.042502
# \t partial train loss (single batch): 0.043337
# \t partial train loss (single batch): 0.043332
# \t partial train loss (single batch): 0.041645
# \t partial train loss (single batch): 0.043777
# \t partial train loss (single batch): 0.042650
# \t partial train loss (single batch): 0.043666
# \t partial train loss (single batch): 0.042569
# \t partial train loss (single batch): 0.041971
# \t partial train loss (single batch): 0.044531
# \t partial train loss (single batch): 0.044956
# \t partial train loss (single batch): 0.042222
# \t partial train loss (single batch): 0.042199
# \t partial train loss (single batch): 0.043896
# \t partial train loss (single batch): 0.042214
# \t partial train loss (single batch): 0.041538
# \t partial train loss (single batch): 0.042565
# \t partial train loss (single batch): 0.041835
# \t partial train loss (single batch): 0.042945
# \t partial train loss (single batch): 0.043180
# \t partial train loss (single batch): 0.041386
# \t partial train loss (single batch): 0.041533
# \t partial train loss (single batch): 0.041828
# \t partial train loss (single batch): 0.041277
# \t partial train loss (single batch): 0.042798
# \t partial train loss (single batch): 0.042129
# \t partial train loss (single batch): 0.041140
# \t partial train loss (single batch): 0.041778
# \t partial train loss (single batch): 0.042691
# \t partial train loss (single batch): 0.041324
# \t partial train loss (single batch): 0.041284
# \t partial train loss (single batch): 0.041446
# \t partial train loss (single batch): 0.040645
# \t partial train loss (single batch): 0.041810
# \t partial train loss (single batch): 0.040190
# \t partial train loss (single batch): 0.040621
# \t partial train loss (single batch): 0.040561
# \t partial train loss (single batch): 0.040829
# \t partial train loss (single batch): 0.040464
# \t partial train loss (single batch): 0.039042
# \t partial train loss (single batch): 0.040226
# \t partial train loss (single batch): 0.039536
# \t partial train loss (single batch): 0.041670
# \t partial train loss (single batch): 0.040015
# \t partial train loss (single batch): 0.040029
# \t partial train loss (single batch): 0.039915
# \t partial train loss (single batch): 0.039637
# \n EPOCH 2/20 \t train loss 0.048 \t val loss 0.040
# \t partial train loss (single batch): 0.040195
# \t partial train loss (single batch): 0.038557
# \t partial train loss (single batch): 0.039691
# \t partial train loss (single batch): 0.039649
# \t partial train loss (single batch): 0.041434
# \t partial train loss (single batch): 0.039804
# \t partial train loss (single batch): 0.039829
# \t partial train loss (single batch): 0.040630
# \t partial train loss (single batch): 0.040213
# \t partial train loss (single batch): 0.039263
# \t partial train loss (single batch): 0.038099
# \t partial train loss (single batch): 0.040001
# \t partial train loss (single batch): 0.040545
# \t partial train loss (single batch): 0.040622
# \t partial train loss (single batch): 0.040172
# \t partial train loss (single batch): 0.040063
# \t partial train loss (single batch): 0.038011
# \t partial train loss (single batch): 0.039190
# \t partial train loss (single batch): 0.037651
# \t partial train loss (single batch): 0.039883
# \t partial train loss (single batch): 0.038656
# \t partial train loss (single batch): 0.040756
# \t partial train loss (single batch): 0.039521
# \t partial train loss (single batch): 0.038543
# \t partial train loss (single batch): 0.039300
# \t partial train loss (single batch): 0.039254
# \t partial train loss (single batch): 0.039224
# \t partial train loss (single batch): 0.038678
# \t partial train loss (single batch): 0.039254
# \t partial train loss (single batch): 0.039845
# \t partial train loss (single batch): 0.038187
# \t partial train loss (single batch): 0.038876
# \t partial train loss (single batch): 0.039786
# \t partial train loss (single batch): 0.037681
# \t partial train loss (single batch): 0.037994
# \t partial train loss (single batch): 0.038216
# \t partial train loss (single batch): 0.038553
# \t partial train loss (single batch): 0.039539
# \t partial train loss (single batch): 0.038715
# \t partial train loss (single batch): 0.037557
# \t partial train loss (single batch): 0.038833
# \t partial train loss (single batch): 0.038420
# \t partial train loss (single batch): 0.038750
# \t partial train loss (single batch): 0.039108
# \t partial train loss (single batch): 0.037972
# \t partial train loss (single batch): 0.038816
# \t partial train loss (single batch): 0.039475
# \t partial train loss (single batch): 0.039720
# \t partial train loss (single batch): 0.036475
# \t partial train loss (single batch): 0.038842
# \t partial train loss (single batch): 0.038224
# \t partial train loss (single batch): 0.039145
# \t partial train loss (single batch): 0.038161
# \t partial train loss (single batch): 0.037146
# \t partial train loss (single batch): 0.040396
# \t partial train loss (single batch): 0.037478
# \t partial train loss (single batch): 0.038150
# \t partial train loss (single batch): 0.037603
# \t partial train loss (single batch): 0.037447
# \t partial train loss (single batch): 0.036207
# \t partial train loss (single batch): 0.038546
# \t partial train loss (single batch): 0.038006
# \t partial train loss (single batch): 0.036323
# \t partial train loss (single batch): 0.037514
# \t partial train loss (single batch): 0.037809
# \t partial train loss (single batch): 0.040455
# \t partial train loss (single batch): 0.038357
# \t partial train loss (single batch): 0.037752
# \t partial train loss (single batch): 0.038076
# \t partial train loss (single batch): 0.036482
# \t partial train loss (single batch): 0.037274
# \t partial train loss (single batch): 0.036006
# \t partial train loss (single batch): 0.036875
# \t partial train loss (single batch): 0.037437
# \t partial train loss (single batch): 0.036436
# \t partial train loss (single batch): 0.037158
# \t partial train loss (single batch): 0.037542
# \t partial train loss (single batch): 0.035858
# \t partial train loss (single batch): 0.037601
# \t partial train loss (single batch): 0.037748
# \t partial train loss (single batch): 0.035962
# \t partial train loss (single batch): 0.036139
# \t partial train loss (single batch): 0.036705
# \t partial train loss (single batch): 0.038446
# \t partial train loss (single batch): 0.036693
# \t partial train loss (single batch): 0.037693
# \t partial train loss (single batch): 0.037542
# \t partial train loss (single batch): 0.035777
# \t partial train loss (single batch): 0.036701
# \t partial train loss (single batch): 0.035475
# \t partial train loss (single batch): 0.038002
# \t partial train loss (single batch): 0.038222
# \t partial train loss (single batch): 0.036916
# \t partial train loss (single batch): 0.038113
# \t partial train loss (single batch): 0.035958
# \t partial train loss (single batch): 0.036828
# \t partial train loss (single batch): 0.036991
# \t partial train loss (single batch): 0.036582
# \t partial train loss (single batch): 0.036398
# \t partial train loss (single batch): 0.036725
# \t partial train loss (single batch): 0.036449
# \t partial train loss (single batch): 0.036304
# \t partial train loss (single batch): 0.035918
# \t partial train loss (single batch): 0.036526
# \t partial train loss (single batch): 0.036876
# \t partial train loss (single batch): 0.036051
# \t partial train loss (single batch): 0.036210
# \t partial train loss (single batch): 0.036342
# \t partial train loss (single batch): 0.035224
# \t partial train loss (single batch): 0.037407
# \t partial train loss (single batch): 0.036397
# \t partial train loss (single batch): 0.035225
# \t partial train loss (single batch): 0.036219
# \t partial train loss (single batch): 0.037458
# \t partial train loss (single batch): 0.035949
# \t partial train loss (single batch): 0.037426
# \t partial train loss (single batch): 0.037419
# \t partial train loss (single batch): 0.035777
# \t partial train loss (single batch): 0.036476
# \t partial train loss (single batch): 0.037560
# \t partial train loss (single batch): 0.034047
# \t partial train loss (single batch): 0.035674
# \t partial train loss (single batch): 0.035900
# \t partial train loss (single batch): 0.035963
# \t partial train loss (single batch): 0.035319
# \t partial train loss (single batch): 0.035640
# \t partial train loss (single batch): 0.036215
# \t partial train loss (single batch): 0.034641
# \t partial train loss (single batch): 0.035622
# \t partial train loss (single batch): 0.035655
# \t partial train loss (single batch): 0.035116
# \t partial train loss (single batch): 0.034665
# \t partial train loss (single batch): 0.034468
# \t partial train loss (single batch): 0.034351
# \t partial train loss (single batch): 0.035488
# \t partial train loss (single batch): 0.036477
# \t partial train loss (single batch): 0.036845
# \t partial train loss (single batch): 0.035176
# \t partial train loss (single batch): 0.035828
# \t partial train loss (single batch): 0.035627
# \t partial train loss (single batch): 0.034585
# \t partial train loss (single batch): 0.034920
# \t partial train loss (single batch): 0.035477
# \t partial train loss (single batch): 0.035622
# \t partial train loss (single batch): 0.033283
# \t partial train loss (single batch): 0.036299
# \t partial train loss (single batch): 0.035289
# \t partial train loss (single batch): 0.036028
# \t partial train loss (single batch): 0.035694
# \t partial train loss (single batch): 0.034589
# \t partial train loss (single batch): 0.037825
# \t partial train loss (single batch): 0.037739
# \t partial train loss (single batch): 0.035477
# \t partial train loss (single batch): 0.035098
# \t partial train loss (single batch): 0.036800
# \t partial train loss (single batch): 0.035420
# \t partial train loss (single batch): 0.034805
# \t partial train loss (single batch): 0.035814
# \t partial train loss (single batch): 0.034974
# \t partial train loss (single batch): 0.036006
# \t partial train loss (single batch): 0.036457
# \t partial train loss (single batch): 0.034707
# \t partial train loss (single batch): 0.034577
# \t partial train loss (single batch): 0.035367
# \t partial train loss (single batch): 0.034518
# \t partial train loss (single batch): 0.036553
# \t partial train loss (single batch): 0.035664
# \t partial train loss (single batch): 0.034551
# \t partial train loss (single batch): 0.035076
# \t partial train loss (single batch): 0.036529
# \t partial train loss (single batch): 0.034548
# \t partial train loss (single batch): 0.034859
# \t partial train loss (single batch): 0.034952
# \t partial train loss (single batch): 0.034326
# \t partial train loss (single batch): 0.035504
# \t partial train loss (single batch): 0.034104
# \t partial train loss (single batch): 0.034321
# \t partial train loss (single batch): 0.034260
# \t partial train loss (single batch): 0.035025
# \t partial train loss (single batch): 0.034302
# \t partial train loss (single batch): 0.032957
# \t partial train loss (single batch): 0.033844
# \t partial train loss (single batch): 0.033399
# \t partial train loss (single batch): 0.035650
# \t partial train loss (single batch): 0.033909
# \t partial train loss (single batch): 0.033945
# \t partial train loss (single batch): 0.033625
# \t partial train loss (single batch): 0.033394
# \n EPOCH 3/20 \t train loss 0.037 \t val loss 0.034
# \t partial train loss (single batch): 0.034170
# \t partial train loss (single batch): 0.032227
# \t partial train loss (single batch): 0.034294
# \t partial train loss (single batch): 0.033895
# \t partial train loss (single batch): 0.035746
# \t partial train loss (single batch): 0.034308
# \t partial train loss (single batch): 0.033912
# \t partial train loss (single batch): 0.034743
# \t partial train loss (single batch): 0.034267
# \t partial train loss (single batch): 0.033663
# \t partial train loss (single batch): 0.032561
# \t partial train loss (single batch): 0.034550
# \t partial train loss (single batch): 0.035256
# \t partial train loss (single batch): 0.035079
# \t partial train loss (single batch): 0.034813
# \t partial train loss (single batch): 0.034613
# \t partial train loss (single batch): 0.032826
# \t partial train loss (single batch): 0.033479
# \t partial train loss (single batch): 0.032032
# \t partial train loss (single batch): 0.034204
# \t partial train loss (single batch): 0.033021
# \t partial train loss (single batch): 0.035678
# \t partial train loss (single batch): 0.034336
# \t partial train loss (single batch): 0.033662
# \t partial train loss (single batch): 0.034508
# \t partial train loss (single batch): 0.033985
# \t partial train loss (single batch): 0.033900
# \t partial train loss (single batch): 0.033786
# \t partial train loss (single batch): 0.034364
# \t partial train loss (single batch): 0.034940
# \t partial train loss (single batch): 0.032836
# \t partial train loss (single batch): 0.034094
# \t partial train loss (single batch): 0.034787
# \t partial train loss (single batch): 0.032298
# \t partial train loss (single batch): 0.033038
# \t partial train loss (single batch): 0.033447
# \t partial train loss (single batch): 0.033740
# \t partial train loss (single batch): 0.034941
# \t partial train loss (single batch): 0.034125
# \t partial train loss (single batch): 0.032389
# \t partial train loss (single batch): 0.034289
# \t partial train loss (single batch): 0.033509
# \t partial train loss (single batch): 0.034508
# \t partial train loss (single batch): 0.034052
# \t partial train loss (single batch): 0.033297
# \t partial train loss (single batch): 0.034100
# \t partial train loss (single batch): 0.034844
# \t partial train loss (single batch): 0.034883
# \t partial train loss (single batch): 0.031576
# \t partial train loss (single batch): 0.034575
# \t partial train loss (single batch): 0.033646
# \t partial train loss (single batch): 0.034452
# \t partial train loss (single batch): 0.033976
# \t partial train loss (single batch): 0.032294
# \t partial train loss (single batch): 0.035870
# \t partial train loss (single batch): 0.032944
# \t partial train loss (single batch): 0.033777
# \t partial train loss (single batch): 0.032993
# \t partial train loss (single batch): 0.033200
# \t partial train loss (single batch): 0.031807
# \t partial train loss (single batch): 0.033913
# \t partial train loss (single batch): 0.033703
# \t partial train loss (single batch): 0.032069
# \t partial train loss (single batch): 0.033189
# \t partial train loss (single batch): 0.033507
# \t partial train loss (single batch): 0.036096
# \t partial train loss (single batch): 0.034205
# \t partial train loss (single batch): 0.033808
# \t partial train loss (single batch): 0.034121
# \t partial train loss (single batch): 0.032305
# \t partial train loss (single batch): 0.033392
# \t partial train loss (single batch): 0.032059
# \t partial train loss (single batch): 0.032659
# \t partial train loss (single batch): 0.033685
# \t partial train loss (single batch): 0.032220
# \t partial train loss (single batch): 0.033657
# \t partial train loss (single batch): 0.033705
# \t partial train loss (single batch): 0.032104
# \t partial train loss (single batch): 0.033095
# \t partial train loss (single batch): 0.033771
# \t partial train loss (single batch): 0.031886
# \t partial train loss (single batch): 0.032033
# \t partial train loss (single batch): 0.032730
# \t partial train loss (single batch): 0.034668
# \t partial train loss (single batch): 0.032704
# \t partial train loss (single batch): 0.033626
# \t partial train loss (single batch): 0.033512
# \t partial train loss (single batch): 0.031713
# \t partial train loss (single batch): 0.033046
# \t partial train loss (single batch): 0.031578
# \t partial train loss (single batch): 0.033732
# \t partial train loss (single batch): 0.034298
# \t partial train loss (single batch): 0.033471
# \t partial train loss (single batch): 0.034579
# \t partial train loss (single batch): 0.032226
# \t partial train loss (single batch): 0.032915
# \t partial train loss (single batch): 0.033157
# \t partial train loss (single batch): 0.032928
# \t partial train loss (single batch): 0.032432
# \t partial train loss (single batch): 0.033258
# \t partial train loss (single batch): 0.032894
# \t partial train loss (single batch): 0.033079
# \t partial train loss (single batch): 0.032489
# \t partial train loss (single batch): 0.033101
# \t partial train loss (single batch): 0.033385
# \t partial train loss (single batch): 0.032250
# \t partial train loss (single batch): 0.032406
# \t partial train loss (single batch): 0.033011
# \t partial train loss (single batch): 0.031601
# \t partial train loss (single batch): 0.033526
# \t partial train loss (single batch): 0.032854
# \t partial train loss (single batch): 0.031605
# \t partial train loss (single batch): 0.032658
# \t partial train loss (single batch): 0.033542
# \t partial train loss (single batch): 0.032496
# \t partial train loss (single batch): 0.033886
# \t partial train loss (single batch): 0.033992
# \t partial train loss (single batch): 0.032492
# \t partial train loss (single batch): 0.033227
# \t partial train loss (single batch): 0.034215
# \t partial train loss (single batch): 0.030723
# \t partial train loss (single batch): 0.032387
# \t partial train loss (single batch): 0.032507
# \t partial train loss (single batch): 0.032585
# \t partial train loss (single batch): 0.031525
# \t partial train loss (single batch): 0.032102
# \t partial train loss (single batch): 0.033028
# \t partial train loss (single batch): 0.031247
# \t partial train loss (single batch): 0.032417
# \t partial train loss (single batch): 0.032849
# \t partial train loss (single batch): 0.032084
# \t partial train loss (single batch): 0.031606
# \t partial train loss (single batch): 0.031432
# \t partial train loss (single batch): 0.031367
# \t partial train loss (single batch): 0.032282
# \t partial train loss (single batch): 0.033380
# \t partial train loss (single batch): 0.033441
# \t partial train loss (single batch): 0.032106
# \t partial train loss (single batch): 0.032722
# \t partial train loss (single batch): 0.032602
# \t partial train loss (single batch): 0.031630
# \t partial train loss (single batch): 0.031878
# \t partial train loss (single batch): 0.032392
# \t partial train loss (single batch): 0.032306
# \t partial train loss (single batch): 0.030153
# \t partial train loss (single batch): 0.033127
# \t partial train loss (single batch): 0.032151
# \t partial train loss (single batch): 0.033232
# \t partial train loss (single batch): 0.032957
# \t partial train loss (single batch): 0.031694
# \t partial train loss (single batch): 0.034980
# \t partial train loss (single batch): 0.034772
# \t partial train loss (single batch): 0.032708
# \t partial train loss (single batch): 0.032128
# \t partial train loss (single batch): 0.033956
# \t partial train loss (single batch): 0.032298
# \t partial train loss (single batch): 0.032220
# \t partial train loss (single batch): 0.033080
# \t partial train loss (single batch): 0.031972
# \t partial train loss (single batch): 0.033346
# \t partial train loss (single batch): 0.033754
# \t partial train loss (single batch): 0.032103
# \t partial train loss (single batch): 0.031780
# \t partial train loss (single batch): 0.032511
# \t partial train loss (single batch): 0.031819
# \t partial train loss (single batch): 0.033856
# \t partial train loss (single batch): 0.032988
# \t partial train loss (single batch): 0.031739
# \t partial train loss (single batch): 0.032421
# \t partial train loss (single batch): 0.033890
# \t partial train loss (single batch): 0.031860
# \t partial train loss (single batch): 0.031767
# \t partial train loss (single batch): 0.032261
# \t partial train loss (single batch): 0.031650
# \t partial train loss (single batch): 0.032828
# \t partial train loss (single batch): 0.031761
# \t partial train loss (single batch): 0.031626
# \t partial train loss (single batch): 0.031421
# \t partial train loss (single batch): 0.032294
# \t partial train loss (single batch): 0.031712
# \t partial train loss (single batch): 0.030383
# \t partial train loss (single batch): 0.031382
# \t partial train loss (single batch): 0.030694
# \t partial train loss (single batch): 0.032771
# \t partial train loss (single batch): 0.031324
# \t partial train loss (single batch): 0.031279
# \t partial train loss (single batch): 0.030903
# \t partial train loss (single batch): 0.030722
# \n EPOCH 4/20 \t train loss 0.033 \t val loss 0.032
# \t partial train loss (single batch): 0.031591
# \t partial train loss (single batch): 0.029460
# \t partial train loss (single batch): 0.031906
# \t partial train loss (single batch): 0.031343
# \t partial train loss (single batch): 0.033062
# \t partial train loss (single batch): 0.031803
# \t partial train loss (single batch): 0.031347
# \t partial train loss (single batch): 0.032028
# \t partial train loss (single batch): 0.031431
# \t partial train loss (single batch): 0.031334
# \t partial train loss (single batch): 0.030239
# \t partial train loss (single batch): 0.032173
# \t partial train loss (single batch): 0.032838
# \t partial train loss (single batch): 0.032645
# \t partial train loss (single batch): 0.032519
# \t partial train loss (single batch): 0.032188
# \t partial train loss (single batch): 0.030480
# \t partial train loss (single batch): 0.031057
# \t partial train loss (single batch): 0.029603
# \t partial train loss (single batch): 0.031557
# \t partial train loss (single batch): 0.030595
# \t partial train loss (single batch): 0.033395
# \t partial train loss (single batch): 0.031967
# \t partial train loss (single batch): 0.031376
# \t partial train loss (single batch): 0.032192
# \t partial train loss (single batch): 0.031593
# \t partial train loss (single batch): 0.031302
# \t partial train loss (single batch): 0.031504
# \t partial train loss (single batch): 0.032088
# \t partial train loss (single batch): 0.032717
# \t partial train loss (single batch): 0.030555
# \t partial train loss (single batch): 0.031981
# \t partial train loss (single batch): 0.032418
# \t partial train loss (single batch): 0.029986
# \t partial train loss (single batch): 0.030808
# \t partial train loss (single batch): 0.031316
# \t partial train loss (single batch): 0.031558
# \t partial train loss (single batch): 0.032895
# \t partial train loss (single batch): 0.032021
# \t partial train loss (single batch): 0.030030
# \t partial train loss (single batch): 0.032338
# \t partial train loss (single batch): 0.031120
# \t partial train loss (single batch): 0.032294
# \t partial train loss (single batch): 0.031761
# \t partial train loss (single batch): 0.031186
# \t partial train loss (single batch): 0.031608
# \t partial train loss (single batch): 0.032624
# \t partial train loss (single batch): 0.032692
# \t partial train loss (single batch): 0.029307
# \t partial train loss (single batch): 0.032637
# \t partial train loss (single batch): 0.031558
# \t partial train loss (single batch): 0.032310
# \t partial train loss (single batch): 0.032207
# \t partial train loss (single batch): 0.030272
# \t partial train loss (single batch): 0.033665
# \t partial train loss (single batch): 0.031106
# \t partial train loss (single batch): 0.031827
# \t partial train loss (single batch): 0.030953
# \t partial train loss (single batch): 0.031227
# \t partial train loss (single batch): 0.029973
# \t partial train loss (single batch): 0.031811
# \t partial train loss (single batch): 0.031855
# \t partial train loss (single batch): 0.030045
# \t partial train loss (single batch): 0.031351
# \t partial train loss (single batch): 0.031737
# \t partial train loss (single batch): 0.033800
# \t partial train loss (single batch): 0.032209
# \t partial train loss (single batch): 0.031987
# \t partial train loss (single batch): 0.032363
# \t partial train loss (single batch): 0.030575
# \t partial train loss (single batch): 0.031537
# \t partial train loss (single batch): 0.030192
# \t partial train loss (single batch): 0.030757
# \t partial train loss (single batch): 0.031621
# \t partial train loss (single batch): 0.030375
# \t partial train loss (single batch): 0.031837
# \t partial train loss (single batch): 0.031871
# \t partial train loss (single batch): 0.030299
# \t partial train loss (single batch): 0.030890
# \t partial train loss (single batch): 0.031916
# \t partial train loss (single batch): 0.029743
# \t partial train loss (single batch): 0.029987
# \t partial train loss (single batch): 0.030807
# \t partial train loss (single batch): 0.032797
# \t partial train loss (single batch): 0.030859
# \t partial train loss (single batch): 0.031631
# \t partial train loss (single batch): 0.031698
# \t partial train loss (single batch): 0.029773
# \t partial train loss (single batch): 0.031359
# \t partial train loss (single batch): 0.029831
# \t partial train loss (single batch): 0.031814
# \t partial train loss (single batch): 0.032292
# \t partial train loss (single batch): 0.031920
# \t partial train loss (single batch): 0.032511
# \t partial train loss (single batch): 0.030637
# \t partial train loss (single batch): 0.031249
# \t partial train loss (single batch): 0.031205
# \t partial train loss (single batch): 0.031238
# \t partial train loss (single batch): 0.030404
# \t partial train loss (single batch): 0.031497
# \t partial train loss (single batch): 0.031188
# \t partial train loss (single batch): 0.031395
# \t partial train loss (single batch): 0.030899
# \t partial train loss (single batch): 0.031468
# \t partial train loss (single batch): 0.031682
# \t partial train loss (single batch): 0.030384
# \t partial train loss (single batch): 0.030741
# \t partial train loss (single batch): 0.031330
# \t partial train loss (single batch): 0.029858
# \t partial train loss (single batch): 0.031647
# \t partial train loss (single batch): 0.031000
# \t partial train loss (single batch): 0.029883
# \t partial train loss (single batch): 0.030969
# \t partial train loss (single batch): 0.031734
# \t partial train loss (single batch): 0.030791
# \t partial train loss (single batch): 0.032208
# \t partial train loss (single batch): 0.032256
# \t partial train loss (single batch): 0.030884
# \t partial train loss (single batch): 0.031562
# \t partial train loss (single batch): 0.032611
# \t partial train loss (single batch): 0.029000
# \t partial train loss (single batch): 0.030891
# \t partial train loss (single batch): 0.030888
# \t partial train loss (single batch): 0.030823
# \t partial train loss (single batch): 0.029657
# \t partial train loss (single batch): 0.030161
# \t partial train loss (single batch): 0.031346
# \t partial train loss (single batch): 0.029667
# \t partial train loss (single batch): 0.030660
# \t partial train loss (single batch): 0.031313
# \t partial train loss (single batch): 0.030443
# \t partial train loss (single batch): 0.030149
# \t partial train loss (single batch): 0.029701
# \t partial train loss (single batch): 0.030011
# \t partial train loss (single batch): 0.030773
# \t partial train loss (single batch): 0.031487
# \t partial train loss (single batch): 0.031804
# \t partial train loss (single batch): 0.030390
# \t partial train loss (single batch): 0.031174
# \t partial train loss (single batch): 0.031011
# \t partial train loss (single batch): 0.030005
# \t partial train loss (single batch): 0.030392
# \t partial train loss (single batch): 0.030757
# \t partial train loss (single batch): 0.030550
# \t partial train loss (single batch): 0.028532
# \t partial train loss (single batch): 0.031491
# \t partial train loss (single batch): 0.030478
# \t partial train loss (single batch): 0.031620
# \t partial train loss (single batch): 0.031380
# \t partial train loss (single batch): 0.030054
# \t partial train loss (single batch): 0.033471
# \t partial train loss (single batch): 0.033294
# \t partial train loss (single batch): 0.031265
# \t partial train loss (single batch): 0.030581
# \t partial train loss (single batch): 0.032518
# \t partial train loss (single batch): 0.030754
# \t partial train loss (single batch): 0.030620
# \t partial train loss (single batch): 0.031763
# \t partial train loss (single batch): 0.030474
# \t partial train loss (single batch): 0.031870
# \t partial train loss (single batch): 0.032296
# \t partial train loss (single batch): 0.030618
# \t partial train loss (single batch): 0.030263
# \t partial train loss (single batch): 0.031046
# \t partial train loss (single batch): 0.030344
# \t partial train loss (single batch): 0.032384
# \t partial train loss (single batch): 0.031624
# \t partial train loss (single batch): 0.030161
# \t partial train loss (single batch): 0.031064
# \t partial train loss (single batch): 0.032441
# \t partial train loss (single batch): 0.030325
# \t partial train loss (single batch): 0.030277
# \t partial train loss (single batch): 0.030648
# \t partial train loss (single batch): 0.030212
# \t partial train loss (single batch): 0.031467
# \t partial train loss (single batch): 0.030428
# \t partial train loss (single batch): 0.030286
# \t partial train loss (single batch): 0.029838
# \t partial train loss (single batch): 0.030980
# \t partial train loss (single batch): 0.030233
# \t partial train loss (single batch): 0.029002
# \t partial train loss (single batch): 0.030133
# \t partial train loss (single batch): 0.029190
# \t partial train loss (single batch): 0.031267
# \t partial train loss (single batch): 0.029881
# \t partial train loss (single batch): 0.029985
# \t partial train loss (single batch): 0.029591
# \t partial train loss (single batch): 0.029220
# \n EPOCH 5/20 \t train loss 0.031 \t val loss 0.031
# \t partial train loss (single batch): 0.030244
# \t partial train loss (single batch): 0.027979
# \t partial train loss (single batch): 0.030408
# \t partial train loss (single batch): 0.029975
# \t partial train loss (single batch): 0.031576
# \t partial train loss (single batch): 0.030605
# \t partial train loss (single batch): 0.030057
# \t partial train loss (single batch): 0.030552
# \t partial train loss (single batch): 0.029941
# \t partial train loss (single batch): 0.030088
# \t partial train loss (single batch): 0.028978
# \t partial train loss (single batch): 0.030949
# \t partial train loss (single batch): 0.031515
# \t partial train loss (single batch): 0.031336
# \t partial train loss (single batch): 0.031370
# \t partial train loss (single batch): 0.030979
# \t partial train loss (single batch): 0.029159
# \t partial train loss (single batch): 0.029877
# \t partial train loss (single batch): 0.028299
# \t partial train loss (single batch): 0.030223
# \t partial train loss (single batch): 0.029208
# \t partial train loss (single batch): 0.032149
# \t partial train loss (single batch): 0.030663
# \t partial train loss (single batch): 0.030237
# \t partial train loss (single batch): 0.030843
# \t partial train loss (single batch): 0.030221
# \t partial train loss (single batch): 0.030024
# \t partial train loss (single batch): 0.030156
# \t partial train loss (single batch): 0.030802
# \t partial train loss (single batch): 0.031377
# \t partial train loss (single batch): 0.029168
# \t partial train loss (single batch): 0.030819
# \t partial train loss (single batch): 0.031168
# \t partial train loss (single batch): 0.028707
# \t partial train loss (single batch): 0.029814
# \t partial train loss (single batch): 0.030101
# \t partial train loss (single batch): 0.030390
# \t partial train loss (single batch): 0.031886
# \t partial train loss (single batch): 0.030599
# \t partial train loss (single batch): 0.028792
# \t partial train loss (single batch): 0.031232
# \t partial train loss (single batch): 0.029750
# \t partial train loss (single batch): 0.031132
# \t partial train loss (single batch): 0.030469
# \t partial train loss (single batch): 0.029947
# \t partial train loss (single batch): 0.030326
# \t partial train loss (single batch): 0.031411
# \t partial train loss (single batch): 0.031527
# \t partial train loss (single batch): 0.028133
# \t partial train loss (single batch): 0.031349
# \t partial train loss (single batch): 0.030420
# \t partial train loss (single batch): 0.031156
# \t partial train loss (single batch): 0.030884
# \t partial train loss (single batch): 0.029222
# \t partial train loss (single batch): 0.032287
# \t partial train loss (single batch): 0.029854
# \t partial train loss (single batch): 0.030652
# \t partial train loss (single batch): 0.029796
# \t partial train loss (single batch): 0.029834
# \t partial train loss (single batch): 0.028891
# \t partial train loss (single batch): 0.030354
# \t partial train loss (single batch): 0.030748
# \t partial train loss (single batch): 0.028873
# \t partial train loss (single batch): 0.029897
# \t partial train loss (single batch): 0.030593
# \t partial train loss (single batch): 0.032498
# \t partial train loss (single batch): 0.030761
# \t partial train loss (single batch): 0.030936
# \t partial train loss (single batch): 0.031073
# \t partial train loss (single batch): 0.029344
# \t partial train loss (single batch): 0.030607
# \t partial train loss (single batch): 0.029085
# \t partial train loss (single batch): 0.029482
# \t partial train loss (single batch): 0.030370
# \t partial train loss (single batch): 0.029276
# ...
# \t partial train loss (single batch): 0.026769
# \t partial train loss (single batch): 0.025541
# \t partial train loss (single batch): 0.027426
# \t partial train loss (single batch): 0.025426
# \t partial train loss (single batch): 0.027086
# \t partial train loss (single batch): 0.026733
# \t partial train loss (single batch): 0.026431
# \t partial train loss (single batch): 0.026466
# \t partial train loss (single batch): 0.028470
# \t partial train loss (single batch): 0.027812
# \t partial train loss (single batch): 0.024204
# \t partial train loss (single batch): 0.027719
# \t partial train loss (single batch): 0.026511
# \t partial train loss (single batch): 0.027595
# \t partial train loss (single batch): 0.027102
# \t partial train loss (single batch): 0.025545
# \t partial train loss (single batch): 0.028436
# \t partial train loss (single batch): 0.026699
# \t partial train loss (single batch): 0.027234
# \t partial train loss (single batch): 0.026476
# \t partial train loss (single batch): 0.025885
# \t partial train loss (single batch): 0.025364
# \t partial train loss (single batch): 0.027013
# \t partial train loss (single batch): 0.026477
# \t partial train loss (single batch): 0.025163
# \t partial train loss (single batch): 0.026221
# \t partial train loss (single batch): 0.026365
# \t partial train loss (single batch): 0.028242
# \t partial train loss (single batch): 0.026829
# \t partial train loss (single batch): 0.026787
# \t partial train loss (single batch): 0.027426
# \t partial train loss (single batch): 0.026097
# \t partial train loss (single batch): 0.026505
# \t partial train loss (single batch): 0.025851
# \t partial train loss (single batch): 0.025680
# \t partial train loss (single batch): 0.026561
# \t partial train loss (single batch): 0.026203
# \t partial train loss (single batch): 0.026806
# \t partial train loss (single batch): 0.026901
# \t partial train loss (single batch): 0.025654
# \t partial train loss (single batch): 0.026290
# \t partial train loss (single batch): 0.027044
# \t partial train loss (single batch): 0.024756
# \t partial train loss (single batch): 0.025267
# \t partial train loss (single batch): 0.026180
# \t partial train loss (single batch): 0.028463
# \t partial train loss (single batch): 0.025978
# \t partial train loss (single batch): 0.027007
# \t partial train loss (single batch): 0.026458
# \t partial train loss (single batch): 0.024546
# \t partial train loss (single batch): 0.026670
# \t partial train loss (single batch): 0.025718
# \t partial train loss (single batch): 0.027035
# \t partial train loss (single batch): 0.027493
# \t partial train loss (single batch): 0.026753
# \t partial train loss (single batch): 0.027280
# \t partial train loss (single batch): 0.026321
# \t partial train loss (single batch): 0.027332
# \t partial train loss (single batch): 0.026806
# \t partial train loss (single batch): 0.026507
# \t partial train loss (single batch): 0.025742
# \t partial train loss (single batch): 0.026407
# \t partial train loss (single batch): 0.026490
# \t partial train loss (single batch): 0.027219
# \t partial train loss (single batch): 0.026533
# \t partial train loss (single batch): 0.026404
# \t partial train loss (single batch): 0.027209
# \t partial train loss (single batch): 0.025681
# \t partial train loss (single batch): 0.025934
# \t partial train loss (single batch): 0.026973
# \t partial train loss (single batch): 0.025060
# \t partial train loss (single batch): 0.026369
# \t partial train loss (single batch): 0.026047
# \t partial train loss (single batch): 0.025197
# \t partial train loss (single batch): 0.026639
# \t partial train loss (single batch): 0.026895
# \t partial train loss (single batch): 0.026135
# \t partial train loss (single batch): 0.027566
# \t partial train loss (single batch): 0.027163
# \t partial train loss (single batch): 0.026190
# \t partial train loss (single batch): 0.026716
# \t partial train loss (single batch): 0.028099
# \t partial train loss (single batch): 0.024335
# \t partial train loss (single batch): 0.026818
# \t partial train loss (single batch): 0.025643
# \t partial train loss (single batch): 0.026162
# \t partial train loss (single batch): 0.025242
# \t partial train loss (single batch): 0.025184
# \t partial train loss (single batch): 0.026792
# \t partial train loss (single batch): 0.025242
# \t partial train loss (single batch): 0.026358
# \t partial train loss (single batch): 0.026392
# \t partial train loss (single batch): 0.026175
# \t partial train loss (single batch): 0.026156
# \t partial train loss (single batch): 0.025586
# \t partial train loss (single batch): 0.025779
# \t partial train loss (single batch): 0.026929
# \t partial train loss (single batch): 0.026835
# \t partial train loss (single batch): 0.027800
# \t partial train loss (single batch): 0.026107
# \t partial train loss (single batch): 0.026411
# \t partial train loss (single batch): 0.026671
# \t partial train loss (single batch): 0.025682
# \t partial train loss (single batch): 0.026023
# \t partial train loss (single batch): 0.026682
# \t partial train loss (single batch): 0.025677
# \t partial train loss (single batch): 0.024328
# \t partial train loss (single batch): 0.027333
# \t partial train loss (single batch): 0.025852
# \t partial train loss (single batch): 0.026992
# \t partial train loss (single batch): 0.026757
# \t partial train loss (single batch): 0.025462
# \t partial train loss (single batch): 0.028872
# \t partial train loss (single batch): 0.028140
# \t partial train loss (single batch): 0.027415
# \t partial train loss (single batch): 0.026250
# \t partial train loss (single batch): 0.028013
# \t partial train loss (single batch): 0.026260
# \t partial train loss (single batch): 0.026581
# \t partial train loss (single batch): 0.027407
# \t partial train loss (single batch): 0.026106
# \t partial train loss (single batch): 0.027410
# \t partial train loss (single batch): 0.027582
# \t partial train loss (single batch): 0.026266
# \t partial train loss (single batch): 0.026051
# \t partial train loss (single batch): 0.026867
# \t partial train loss (single batch): 0.026560
# \t partial train loss (single batch): 0.027418
# \t partial train loss (single batch): 0.027169
# \t partial train loss (single batch): 0.026182
# \t partial train loss (single batch): 0.026810
# \t partial train loss (single batch): 0.028063
# \t partial train loss (single batch): 0.025737
# \t partial train loss (single batch): 0.025980
# \t partial train loss (single batch): 0.026305
# \t partial train loss (single batch): 0.026581
# \t partial train loss (single batch): 0.027286
# \t partial train loss (single batch): 0.026128
# \t partial train loss (single batch): 0.025884
# \t partial train loss (single batch): 0.026037
# \t partial train loss (single batch): 0.027059
# \t partial train loss (single batch): 0.026177
# \t partial train loss (single batch): 0.024829
# \t partial train loss (single batch): 0.026106
# \t partial train loss (single batch): 0.025263
# \t partial train loss (single batch): 0.027067
# \t partial train loss (single batch): 0.025346
# \t partial train loss (single batch): 0.026187
# \t partial train loss (single batch): 0.025599
# \t partial train loss (single batch): 0.024606
# \n EPOCH 19/20 \t train loss 0.026 \t val loss 0.027
# \t partial train loss (single batch): 0.026766
# \t partial train loss (single batch): 0.024237
# \t partial train loss (single batch): 0.025632
# \t partial train loss (single batch): 0.025826
# \t partial train loss (single batch): 0.026943
# \t partial train loss (single batch): 0.026698
# \t partial train loss (single batch): 0.025775
# \t partial train loss (single batch): 0.026123
# \t partial train loss (single batch): 0.025952
# \t partial train loss (single batch): 0.025781
# \t partial train loss (single batch): 0.025296
# \t partial train loss (single batch): 0.026875
# \t partial train loss (single batch): 0.027458
# \t partial train loss (single batch): 0.026940
# \t partial train loss (single batch): 0.027071
# \t partial train loss (single batch): 0.027381
# \t partial train loss (single batch): 0.025139
# \t partial train loss (single batch): 0.026045
# \t partial train loss (single batch): 0.024094
# \t partial train loss (single batch): 0.026206
# \t partial train loss (single batch): 0.025070
# \t partial train loss (single batch): 0.027903
# \t partial train loss (single batch): 0.026123
# \t partial train loss (single batch): 0.026012
# \t partial train loss (single batch): 0.026627
# \t partial train loss (single batch): 0.026197
# \t partial train loss (single batch): 0.026387
# \t partial train loss (single batch): 0.026170
# \t partial train loss (single batch): 0.026370
# \t partial train loss (single batch): 0.027458
# \t partial train loss (single batch): 0.025197
# \t partial train loss (single batch): 0.027012
# \t partial train loss (single batch): 0.027327
# \t partial train loss (single batch): 0.024161
# \t partial train loss (single batch): 0.025759
# \t partial train loss (single batch): 0.025669
# \t partial train loss (single batch): 0.026573
# \t partial train loss (single batch): 0.027709
# \t partial train loss (single batch): 0.026672
# \t partial train loss (single batch): 0.025419
# \t partial train loss (single batch): 0.027329
# \t partial train loss (single batch): 0.025299
# \t partial train loss (single batch): 0.026975
# \t partial train loss (single batch): 0.026637
# \t partial train loss (single batch): 0.026359
# \t partial train loss (single batch): 0.026280
# \t partial train loss (single batch): 0.028381
# \t partial train loss (single batch): 0.027790
# \t partial train loss (single batch): 0.024088
# \t partial train loss (single batch): 0.027591
# \t partial train loss (single batch): 0.026490
# \t partial train loss (single batch): 0.027567
# \t partial train loss (single batch): 0.026939
# \t partial train loss (single batch): 0.025510
# \t partial train loss (single batch): 0.028398
# \t partial train loss (single batch): 0.026735
# \t partial train loss (single batch): 0.027152
# \t partial train loss (single batch): 0.026310
# \t partial train loss (single batch): 0.025876
# \t partial train loss (single batch): 0.025258
# \t partial train loss (single batch): 0.026796
# \t partial train loss (single batch): 0.026397
# \t partial train loss (single batch): 0.024963
# \t partial train loss (single batch): 0.026126
# \t partial train loss (single batch): 0.026349
# \t partial train loss (single batch): 0.028097
# \t partial train loss (single batch): 0.026790
# \t partial train loss (single batch): 0.026673
# \t partial train loss (single batch): 0.027318
# \t partial train loss (single batch): 0.025938
# \t partial train loss (single batch): 0.026448
# \t partial train loss (single batch): 0.025751
# \t partial train loss (single batch): 0.025646
# \t partial train loss (single batch): 0.026536
# \t partial train loss (single batch): 0.026191
# \t partial train loss (single batch): 0.026725
# \t partial train loss (single batch): 0.026826
# \t partial train loss (single batch): 0.025638
# \t partial train loss (single batch): 0.026285
# \t partial train loss (single batch): 0.026948
# \t partial train loss (single batch): 0.024674
# \t partial train loss (single batch): 0.025169
# \t partial train loss (single batch): 0.026068
# \t partial train loss (single batch): 0.028339
# \t partial train loss (single batch): 0.025900
# \t partial train loss (single batch): 0.026991
# \t partial train loss (single batch): 0.026379
# \t partial train loss (single batch): 0.024454
# \t partial train loss (single batch): 0.026620
# \t partial train loss (single batch): 0.025642
# \t partial train loss (single batch): 0.026963
# \t partial train loss (single batch): 0.027386
# \t partial train loss (single batch): 0.026640
# \t partial train loss (single batch): 0.027194
# \t partial train loss (single batch): 0.026266
# \t partial train loss (single batch): 0.027218
# \t partial train loss (single batch): 0.026743
# \t partial train loss (single batch): 0.026406
# \t partial train loss (single batch): 0.025690
# \t partial train loss (single batch): 0.026283
# \t partial train loss (single batch): 0.026442
# \t partial train loss (single batch): 0.027141
# \t partial train loss (single batch): 0.026467
# \t partial train loss (single batch): 0.026345
# \t partial train loss (single batch): 0.027094
# \t partial train loss (single batch): 0.025602
# \t partial train loss (single batch): 0.025839
# \t partial train loss (single batch): 0.026853
# \t partial train loss (single batch): 0.024932
# \t partial train loss (single batch): 0.026293
# \t partial train loss (single batch): 0.025939
# \t partial train loss (single batch): 0.025143
# \t partial train loss (single batch): 0.026582
# \t partial train loss (single batch): 0.026813
# \t partial train loss (single batch): 0.025989
# \t partial train loss (single batch): 0.027380
# \t partial train loss (single batch): 0.027010
# \t partial train loss (single batch): 0.026098
# \t partial train loss (single batch): 0.026573
# \t partial train loss (single batch): 0.027967
# \t partial train loss (single batch): 0.024255
# \t partial train loss (single batch): 0.026685
# \t partial train loss (single batch): 0.025570
# \t partial train loss (single batch): 0.026048
# \t partial train loss (single batch): 0.025175
# \t partial train loss (single batch): 0.025130
# \t partial train loss (single batch): 0.026654
# \t partial train loss (single batch): 0.025147
# \t partial train loss (single batch): 0.026257
# \t partial train loss (single batch): 0.026320
# \t partial train loss (single batch): 0.026136
# \t partial train loss (single batch): 0.026088
# \t partial train loss (single batch): 0.025488
# \t partial train loss (single batch): 0.025690
# \t partial train loss (single batch): 0.026920
# \t partial train loss (single batch): 0.026758
# \t partial train loss (single batch): 0.027711
# \t partial train loss (single batch): 0.025990
# \t partial train loss (single batch): 0.026323
# \t partial train loss (single batch): 0.026581
# \t partial train loss (single batch): 0.025588
# \t partial train loss (single batch): 0.025949
# \t partial train loss (single batch): 0.026552
# \t partial train loss (single batch): 0.025611
# \t partial train loss (single batch): 0.024248
# \t partial train loss (single batch): 0.027251
# \t partial train loss (single batch): 0.025750
# \t partial train loss (single batch): 0.026907
# \t partial train loss (single batch): 0.026653
# \t partial train loss (single batch): 0.025314
# \t partial train loss (single batch): 0.028769
# \t partial train loss (single batch): 0.028068
# \t partial train loss (single batch): 0.027294
# \t partial train loss (single batch): 0.026149
# \t partial train loss (single batch): 0.027964
# \t partial train loss (single batch): 0.026184
# \t partial train loss (single batch): 0.026541
# \t partial train loss (single batch): 0.027374
# \t partial train loss (single batch): 0.026080
# \t partial train loss (single batch): 0.027265
# \t partial train loss (single batch): 0.027395
# \t partial train loss (single batch): 0.026143
# \t partial train loss (single batch): 0.025922
# \t partial train loss (single batch): 0.026805
# \t partial train loss (single batch): 0.026458
# \t partial train loss (single batch): 0.027283
# \t partial train loss (single batch): 0.027085
# \t partial train loss (single batch): 0.026085
# \t partial train loss (single batch): 0.026724
# \t partial train loss (single batch): 0.027967
# \t partial train loss (single batch): 0.025597
# \t partial train loss (single batch): 0.025863
# \t partial train loss (single batch): 0.026212
# \t partial train loss (single batch): 0.026486
# \t partial train loss (single batch): 0.027162
# \t partial train loss (single batch): 0.025987
# \t partial train loss (single batch): 0.025750
# \t partial train loss (single batch): 0.025961
# \t partial train loss (single batch): 0.026932
# \t partial train loss (single batch): 0.026113
# \t partial train loss (single batch): 0.024712
# \t partial train loss (single batch): 0.026025
# \t partial train loss (single batch): 0.025217
# \t partial train loss (single batch): 0.027004
# \t partial train loss (single batch): 0.025242
# \t partial train loss (single batch): 0.026149
# \t partial train loss (single batch): 0.025530
# \t partial train loss (single batch): 0.024511
# \n EPOCH 20/20 \t train loss 0.026 \t val loss 0.027

# %%
test_epoch(encoder,decoder,device,test_loader,loss_fn).item()
# Out:
# 0.0269478727132082

# %%
# Train and validation loss

plt.figure(figsize=(7,5))
plt.semilogy(history['train_loss'], label='Train')
plt.semilogy(history['val_loss'], label='Valid')
plt.xlabel('Epoch')
plt.ylabel('Average Loss')
#plt.grid()
plt.legend()
#plt.title('loss')
plt.show()
